# %%
import numpy as np
import arviz as az
import matplotlib.pyplot as plt
import hopsy
import x3cflux
x3cflux.logging.level = 0

# %% [markdown]
# # Multi-Level Delayed Acceptance

# %% [markdown]
# ## Setup
#
# First, load the data from FluxML. The corresponding labeling model has 60 DOF.

# %%
simulator_hf = x3cflux.create_simulator_from_fml("spiralus_inst.fml")
simulator_hf.parameter_space.num_free_parameters
# Out:
# 9

# %% [markdown]
# Preconfigured relative/absolute tolerance for the forward simulation and the gradient are $10^{-6}$/$10^{-9}$.

# %%
simulator_hf.builder.solver.relative_tolerance, simulator_hf.builder.derivative_solver.relative_tolerance
# Out:
# (1e-06, 1e-06)

# %% [markdown]
# Now, create a mid fidelity simulator which only uses $10^{-3}$/$10^{-6}$ for simulation and gradient.

# %%
simulator_mf = x3cflux.create_simulator_from_fml("spiralus_inst.fml")
simulator_mf.builder.solver.relative_tolerance = 1e-3
simulator_mf.builder.solver.absolute_tolerance = 1e-5
simulator_mf.builder.derivative_solver.relative_tolerance = 1e-3
simulator_mf.builder.derivative_solver.absolute_tolerance = 1e-5

# %% [markdown]
# same for a low fidelity simulator

# %%
simulator_lf = x3cflux.create_simulator_from_fml("spiralus_inst.fml")
simulator_lf.builder.solver.relative_tolerance = 1e-1
simulator_lf.builder.solver.absolute_tolerance = 1e-2
simulator_lf.builder.derivative_solver.relative_tolerance = 1e-1
simulator_lf.builder.derivative_solver.absolute_tolerance = 1e-2

# %% [markdown]
# Get an inital point in the polytope and check how the simulation speeds differ.

# %%
ineq_sys = simulator_hf.parameter_space.inequality_system
initial_point = x3cflux.get_parameters(simulator_hf.parameter_space, simulator_hf.configurations[0].parameter_entries) #starting_point

# %%
#%timeit simulator_hf.compute_loss(initial_point)

# %%
# %timeit simulator_mf.compute_loss(initial_point)
# Out:
# 2.53 ms ± 433 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit simulator_lf.compute_loss(initial_point)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'simulator_lf.compute_loss(initial_point)')
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/IPython/core/magics/execution.py:1230, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1227         if time_number >= 0.2:
#    1228             break
# -> 1230 all_runs = timer.repeat(repeat, number)
#    1231 best = min(all_runs) / number
#    1232 worst = max(all_runs) / number
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/IPython/core/magics/execution.py:184, in Timer.timeit(self, number)
#     182 gc.disable()
#     183 try:
# --> 184     timing = self.inner(it, self.timer)
#     185 finally:
#     186     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Define the Multi-Level Delayed Acceptance proposal

# %%
class DelayedAcceptanceProposal:
    def __init__(self, problem: hopsy.Problem, problem_lf: hopsy.Problem, proposal_object,length: int = 10):
        self.problem = problem
        self.state = self.proposal = problem.starting_point
        self.state_log_density = problem.model.log_density(self.state)
        self.proposal_log_density = self.state_log_density
    
        init_chain_lf = hopsy.MarkovChain(problem_lf,starting_point=self.state)
        init_chain_lf.proposal=proposal_object
        self.chain_lf = init_chain_lf
        print(self.chain_lf)
        self.length: int = length
        self.state_log_density_lf = self.chain_lf.state_log_density

    def propose(self, rng: hopsy.RandomNumberGenerator) -> np.ndarray:
        self.chain_lf.state = self.state
        for i in range(self.length):
            self.chain_lf.draw(rng)
        self.proposal = self.chain_lf.state
        self.proposal_log_density = self.problem.model.log_density(self.proposal)
        return self.proposal
    
    def accept_proposal(self) -> np.ndarray:
        self.state = self.proposal
        self.state_log_density = self.proposal_log_density
        self.state_log_density_lf = self.chain_lf.state_log_density
        return self.state

    def log_acceptance_probability(self) -> float:
        return self.proposal_log_density - self.state_log_density + \
            self.state_log_density_lf - self.chain_lf.state_log_density

# %%
def configure_mlda(models : hopsy.Problem, chain_lengths: int, mh_proposal: hopsy.Proposal, starting_point):
    
    levels = len(models)
    
    da_proposals = [mh_proposal(models[0],starting_point)]     
    
    for l in range(1,levels):
        da_proposals[l] = DelayedAcceptanceProposal(models[l],models[l-1],proposal_object=da_proposals[l-1],length = chain_lengths[l])
    return da_proposals[levels-1]

# %% [markdown]
# ## Sample models

# %%
problem_0 = hopsy.Problem(ineq_sys.matrix, ineq_sys.bound, x3cflux.HopsyModel(simulator_lf))
problem_0.starting_point = initial_point

problem_1 = hopsy.Problem(ineq_sys.matrix, ineq_sys.bound, x3cflux.HopsyModel(simulator_mf))
problem_1.starting_point = initial_point

problem_2 = hopsy.Problem(ineq_sys.matrix, ineq_sys.bound, x3cflux.HopsyModel(simulator_hf)) 
problem_2.starting_point = initial_point

MLDA_01 = DelayedAcceptanceProposal(problem_1,problem_0, proposal_object=hopsy.GaussianHitAndRunProposal(problem_0), length = 5)
MLDA_12 = DelayedAcceptanceProposal(problem_2,problem_1, proposal_object=MLDA_01,length = 2)
chain = hopsy.MarkovChain(problem_2)
chain.proposal = MLDA_12 
rng = hopsy.RandomNumberGenerator(42)
# Out:
# <hopsy.core.MarkovChain object at 0x7ff2932dc7b0>
# <hopsy.core.MarkovChain object at 0x7ff292d79370>

# %%
n_samples = 10000

# %%
meta, samples = hopsy.sample(chain, rng, n_samples, record_meta=["acceptance_rate", "state_log_density"], progress_bar=True)
# Out:
# chain 0:   0%|          | 0/10000 [00:00<?, ?it/s]
# chain 0:   2%|▏         | 197/10000 [00:07<06:38, 24.63it/s]
# /home/henning/miniforge3/envs/13CFlux/lib/python3.13/site-packages/hopsy/misc.py:684: SyntaxWarning: invalid escape sequence '\l'
#   Computes the Chebyshev center, that is the midpoint of a (non-unique) largest inscribed ball in the polytope defined by :math:`Ax \leq b`.
# /home/henning/miniforge3/envs/13CFlux/lib/python3.13/site-packages/hopsy/misc.py:785: SyntaxWarning: invalid escape sequence '\l'
#   Rounds the polytope defined by the inequality :math:`Ax \leq b` using
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 meta, samples = hopsy.sample(chain, rng, n_samples, record_meta=["acceptance_rate", "state_log_density"], progress_bar=True)
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/hopsy/misc.py:1310, in sample(markov_chains, rngs, n_samples, thinning, n_threads, n_procs, record_meta, in_memory, callback, progress_bar)
#    1308 else:
#    1309     for chain_idx in range(len(markov_chains)):
# -> 1310         _accrates, _states = _sequential_sampling(
#    1311             markov_chains[chain_idx],
#    1312             rngs[chain_idx],
#    1313             n_samples,
#    1314             thinning,
#    1315             chain_idx,
#    1316             in_memory,
#    1317             record_meta,
#    1318             callback,
#    1319             progress_bar,
#    1320         )
#    1321         result.append((_accrates, _states))
#    1323 if in_memory:
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/hopsy/misc.py:937, in _sequential_sampling(markov_chain, rng, n_samples, thinning, chain_idx, in_memory, record_meta, callback, progress_bar)
#     931 sample_range = (
#     932     _s.tqdm.trange(n_samples, desc="chain {}".format(chain_idx))
#     933     if progress_bar
#     934     else range(n_samples)
#     935 )
#     936 for i in sample_range:
# --> 937     accrate, state = markov_chain.draw(rng, thinning)
#     939     curr_meta = None
#     940     if record_meta is None or record_meta is False:
#
# Cell In[35], line 20, in DelayedAcceptanceProposal.propose(self, rng)
#      18     self.chain_lf.draw(rng)
#      19 self.proposal = self.chain_lf.state
# ---> 20 self.proposal_log_density = self.problem.model.log_density(self.proposal)
#      21 return self.proposal
#
# File ~/miniforge3/envs/13CFlux/lib/python3.13/site-packages/x3cflux/statistics.py:785, in HopsyModel.log_density(self, x)
#     775 def log_density(self, x):
#     776     r"""
#     777     Compute log likelihood up to a constant. This is equal to
#     778     .. math:: -\frac{1}{2} SSR(\boldsymbol \theta)
#    (...)    783         Negative log likelihood value
#     784     """
# --> 785     return -0.5 * self.simulator.compute_loss(x)
#
# KeyboardInterrupt:

# %%
test_meta["acceptance_rate"].mean(axis=1)
# Out:
# array([0.3919, 0.3773, 0.401 , 0.3996])

# %%
test_chains = [hopsy.MarkovChain(problem_2,proposal=hopsy.CSmMALAProposal, starting_point = initial_point) for i in range(4)]

for mc in test_chains:
    mc.proposal.stepsize = 0.5
    mc.proposal.fisher_weight = 0.9

test_rngs = [hopsy.RandomNumberGenerator(seed = (i+5)*42) for i in range(4)]

test_meta, test_samples = hopsy.sample(test_chains,test_rngs,n_samples=n_samples,record_meta=["acceptance_rate", "state_log_density"],progress_bar=True,n_procs=6)
# Out:
# chain 0:   0%|          | 0/10000 [00:00<?, ?it/s]
# Pool size of metabolite "G" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "F" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "G" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "F" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "G" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "F" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "G" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# Pool size of metabolite "F" is non-determinable given the measurement configuration, as it does not impact the simulation outcome. Consider fixing the pool size in FluxML to reduce the ill-conditionedness of the inverse problem.
# chain 0:   0%|          | 1/10000 [00:05<14:59:33,  5.40s/it]
#
#
#
#
# chain 0:   0%|          | 2/10000 [00:06<7:11:49,  2.59s/it]
#
#
# chain 0:   0%|          | 4/10000 [00:06<2:55:56,  1.06s/it]
#
#
# chain 0:   0%|          | 5/10000 [00:06<2:12:05,  1.26it/s]
#
#
# chain 0:   0%|          | 6/10000 [00:07<1:49:13,  1.52it/s]
#
#
#
#
# chain 0:   0%|          | 7/10000 [00:07<1:39:59,  1.67it/s]
#
#
# chain 0:   0%|          | 8/10000 [00:08<1:28:39,  1.88it/s]
#
#
# chain 0:   0%|          | 10/10000 [00:08<1:02:32,  2.66it/s]
#
#
#
#
#
# chain 0:   0%|          | 11/10000 [00:09<1:06:17,  2.51it/s]
#
#
#
#
#
#
# chain 0:   0%|          | 12/10000 [00:09<1:20:38,  2.06it/s]
#
#
#
# chain 0:   0%|          | 13/10000 [00:10<1:20:08,  2.08it/s]
#
#
#
#
#
#
# chain 0:   0%|          | 15/10000 [00:10<1:02:58,  2.64it/s]
#
#
#
#
# chain 0:   0%|          | 16/10000 [00:11<1:10:26,  2.36it/s]
#
#
# chain 0:   0%|          | 17/10000 [00:11<1:09:42,  2.39it/s]
#
#
#
#
#
#
# chain 0:   0%|          | 18/10000 [00:12<1:17:11,  2.16it/s]
#
#
#
#
#
#
# chain 0:   0%|          | 19/10000 [00:12<1:19:11,  2.10it/s]
#
#
# chain 0:   0%|          | 20/10000 [00:13<1:20:29,  2.07it/s]
#
#
#
#
#
# chain 0:   0%|          | 22/10000 [00:13<1:04:28,  2.58it/s]
#
#
# chain 0:   0%|          | 23/10000 [00:14<1:02:53,  2.64it/s]
#
#
# chain 0:   0%|          | 25/10000 [00:14<50:39,  3.28it/s]
#
#
# chain 0:   0%|          | 26/10000 [00:15<50:57,  3.26it/s]
#
#
#
#
#
#
# chain 0:   0%|          | 27/10000 [00:15<1:05:55,  2.52it/s]
#
#
# chain 0:   0%|          | 28/10000 [00:16<1:09:28,  2.39it/s]
# chain 0:   0%|          | 29/10000 [00:16<59:53,  2.77it/s]
#
# chain 0:   0%|          | 31/10000 [00:16<47:20,  3.51it/s]
# chain 0:   0%|          | 32/10000 [00:17<44:08,  3.76it/s]
#
# chain 0:   0%|          | 33/10000 [00:17<46:47,  3.55it/s]
#
# chain 0:   0%|          | 34/10000 [00:17<49:29,  3.36it/s]
# chain 0:   0%|          | 36/10000 [00:18<40:40,  4.08it/s]
#
# chain 0:   0%|          | 37/10000 [00:18<42:34,  3.90it/s]
#
# chain 0:   0%|          | 38/10000 [00:18<56:55,  2.92it/s]
#
# chain 0:   0%|          | 39/10000 [00:19<1:06:03,  2.51it/s]
#
#
#
#
# chain 0:   0%|          | 40/10000 [00:20<1:16:53,  2.16it/s]
#
#
# chain 0:   0%|          | 41/10000 [00:20<1:18:44,  2.11it/s]
#
#
#
# chain 0:   0%|          | 42/10000 [00:21<1:25:56,  1.93it/s]
#
# chain 0:   0%|          | 43/10000 [00:21<1:17:20,  2.15it/s]
#
#
#
# chain 0:   0%|          | 44/10000 [00:21<1:16:38,  2.17it/s]
#
#
#
# chain 0:   0%|          | 45/10000 [00:22<1:16:10,  2.18it/s]
#
#
#
#
#
#
#
# chain 0:   0%|          | 46/10000 [00:22<1:20:49,  2.05it/s]
#
#
# chain 0:   0%|          | 47/10000 [00:23<1:15:48,  2.19it/s]
#
#
# chain 0:   0%|          | 49/10000 [00:23<55:51,  2.97it/s]
#
#
#
#
# chain 0:   0%|          | 50/10000 [00:24<1:03:03,  2.63it/s]
#
#
# chain 0:   1%|          | 51/10000 [00:24<57:34,  2.88it/s]
#
#
# chain 0:   1%|          | 52/10000 [00:24<1:00:33,  2.74it/s]
#
#
#
#
#
# chain 0:   1%|          | 53/10000 [00:25<1:12:15,  2.29it/s]
#
#
#
#
# chain 0:   1%|          | 54/10000 [00:26<1:12:13,  2.30it/s]
#
#
#
#
# chain 0:   1%|          | 55/10000 [00:26<1:06:00,  2.51it/s]
#
#
#
#
#
# chain 0:   1%|          | 56/10000 [00:26<1:14:38,  2.22it/s]
#
#
# chain 0:   1%|          | 57/10000 [00:27<1:14:27,  2.23it/s]
#
# chain 0:   1%|          | 58/10000 [00:27<1:10:42,  2.34it/s]
#
#
# chain 0:   1%|          | 59/10000 [00:28<1:07:07,  2.47it/s]
#
#
# chain 0:   1%|          | 60/10000 [00:28<1:04:58,  2.55it/s]
#
#
# chain 0:   1%|          | 61/10000 [00:28<59:23,  2.79it/s]
#
#
# chain 0:   1%|          | 62/10000 [00:29<1:03:00,  2.63it/s]
#
#
# chain 0:   1%|          | 63/10000 [00:29<1:01:25,  2.70it/s]
#
#
# chain 0:   1%|          | 64/10000 [00:29<1:03:45,  2.60it/s]
#
#
#
#
# chain 0:   1%|          | 65/10000 [00:30<1:07:29,  2.45it/s]
#
#
# chain 0:   1%|          | 66/10000 [00:30<1:05:30,  2.53it/s]
#
#
# chain 0:   1%|          | 67/10000 [00:31<1:11:00,  2.33it/s]
#
#
#
# chain 0:   1%|          | 68/10000 [00:31<1:12:46,  2.27it/s]
#
#
# chain 0:   1%|          | 69/10000 [00:32<1:06:29,  2.49it/s]
# chain 0:   1%|          | 70/10000 [00:32<58:36,  2.82it/s]
#
#
#
# chain 0:   1%|          | 71/10000 [00:32<59:26,  2.78it/s]
#
#
# chain 0:   1%|          | 72/10000 [00:33<1:13:35,  2.25it/s]
#
#
#
#
# chain 0:   1%|          | 73/10000 [00:33<1:10:48,  2.34it/s]
#
#
#
#
#
# chain 0:   1%|          | 75/10000 [00:34<1:02:36,  2.64it/s]
#
#
#
# chain 0:   1%|          | 76/10000 [00:34<58:30,  2.83it/s]
#
#
# chain 0:   1%|          | 77/10000 [00:34<54:35,  3.03it/s]
#
# chain 0:   1%|          | 78/10000 [00:35<1:00:15,  2.74it/s]
#
#
# chain 0:   1%|          | 79/10000 [00:35<1:02:58,  2.63it/s]
#
#
#
#
#
# chain 0:   1%|          | 80/10000 [00:36<1:12:45,  2.27it/s]
#
#
#
#
#
# chain 0:   1%|          | 81/10000 [00:36<1:18:27,  2.11it/s]
#
#
# chain 0:   1%|          | 82/10000 [00:37<1:12:23,  2.28it/s]
#
#
# chain 0:   1%|          | 83/10000 [00:37<1:15:05,  2.20it/s]
#
#
#
#
#
#
#
# chain 0:   1%|          | 84/10000 [00:38<1:30:11,  1.83it/s]
# chain 0:   1%|          | 85/10000 [00:38<1:16:28,  2.16it/s]
#
#
#
# chain 0:   1%|          | 86/10000 [00:39<1:08:48,  2.40it/s]
#
#
# chain 0:   1%|          | 87/10000 [00:39<1:02:49,  2.63it/s]
#
#
# chain 0:   1%|          | 88/10000 [00:39<1:00:03,  2.75it/s]
#
#
# chain 0:   1%|          | 89/10000 [00:40<1:00:34,  2.73it/s]
#
# chain 0:   1%|          | 90/10000 [00:40<51:06,  3.23it/s]
#
#
#
# chain 0:   1%|          | 91/10000 [00:40<56:14,  2.94it/s]
#
#
#
#
# chain 0:   1%|          | 92/10000 [00:40<54:49,  3.01it/s]
#
#
# chain 0:   1%|          | 93/10000 [00:41<54:07,  3.05it/s]
#
#
#
# chain 0:   1%|          | 94/10000 [00:41<53:18,  3.10it/s]
#
#
#
# chain 0:   1%|          | 95/10000 [00:41<48:15,  3.42it/s]
#
#
#
#
# chain 0:   1%|          | 96/10000 [00:42<47:25,  3.48it/s]
#
# chain 0:   1%|          | 97/10000 [00:42<45:07,  3.66it/s]
# chain 0:   1%|          | 98/10000 [00:42<42:55,  3.85it/s]
#
#
#
#
#
# chain 0:   1%|          | 100/10000 [00:43<44:49,  3.68it/s]
#
#
#
#
# chain 0:   1%|          | 101/10000 [00:43<55:08,  2.99it/s]
#
#
#
#
# chain 0:   1%|          | 102/10000 [00:44<57:23,  2.87it/s]
#
# chain 0:   1%|          | 103/10000 [00:44<57:01,  2.89it/s]
#
#
#
#
#
#
#
# chain 0:   1%|          | 104/10000 [00:45<1:16:26,  2.16it/s]
#
#
# chain 0:   1%|          | 105/10000 [00:46<1:38:39,  1.67it/s]
#
#
#
# chain 0:   1%|          | 106/10000 [00:46<1:28:20,  1.87it/s]
#
#
#
#
#
#
#
# chain 0:   1%|          | 107/10000 [00:47<1:34:49,  1.74it/s]
#
#
#
# chain 0:   1%|          | 109/10000 [00:47<1:07:17,  2.45it/s]
#
#
#
#
#
#
#
# chain 0:   1%|          | 110/10000 [00:48<1:15:13,  2.19it/s]
#
#
#
#
#
#
#
#
#
# chain 0:   1%|          | 111/10000 [00:49<1:36:28,  1.71it/s]
#
#
#
#
# chain 0:   1%|          | 112/10000 [00:49<1:37:46,  1.69it/s]
#
#
# chain 0:   1%|          | 113/10000 [00:50<1:24:45,  1.94it/s]
#
#
#
# chain 0:   1%|          | 114/10000 [00:50<1:30:35,  1.82it/s]
#
#
#
# chain 0:   1%|          | 115/10000 [00:51<1:45:09,  1.57it/s]
#
#
#
# chain 0:   1%|          | 116/10000 [00:52<1:40:47,  1.63it/s]
#
#
#
#
# chain 0:   1%|          | 117/10000 [00:52<1:49:09,  1.51it/s]
#
#
# chain 0:   1%|          | 118/10000 [00:53<1:35:51,  1.72it/s]
#
#
#
#
#
# chain 0:   1%|          | 119/10000 [00:54<1:44:56,  1.57it/s]
# chain 0:   1%|          | 120/10000 [00:54<1:34:58,  1.73it/s]
#
#
#
# chain 0:   1%|          | 121/10000 [00:55<1:44:23,  1.58it/s]
#
#
#
# chain 0:   1%|          | 122/10000 [00:55<1:43:59,  1.58it/s]
#
#
# chain 0:   1%|          | 123/10000 [00:56<1:33:18,  1.76it/s]
#
#
# chain 0:   1%|          | 124/10000 [00:56<1:34:27,  1.74it/s]
#
# chain 0:   1%|▏         | 125/10000 [00:57<1:26:42,  1.90it/s]
#
#
#
# chain 0:   1%|▏         | 126/10000 [00:57<1:28:39,  1.86it/s]
#
#
# chain 0:   1%|▏         | 127/10000 [00:58<1:22:30,  1.99it/s]
#
#
# chain 0:   1%|▏         | 128/10000 [00:58<1:16:17,  2.16it/s]
#
# chain 0:   1%|▏         | 129/10000 [00:59<1:23:48,  1.96it/s]
#
#
#
#
#
# chain 0:   1%|▏         | 130/10000 [00:59<1:28:15,  1.86it/s]
#
#
# chain 0:   1%|▏         | 131/10000 [01:00<1:16:00,  2.16it/s]
#
#
# chain 0:   1%|▏         | 132/10000 [01:00<1:06:31,  2.47it/s]
#
#
# chain 0:   1%|▏         | 133/10000 [01:01<1:15:22,  2.18it/s]
#
#
#
#
# chain 0:   1%|▏         | 134/10000 [01:01<1:21:52,  2.01it/s]
#
#
# chain 0:   1%|▏         | 135/10000 [01:02<1:26:02,  1.91it/s]
#
#
#
#
#
# chain 0:   1%|▏         | 136/10000 [01:02<1:33:30,  1.76it/s]
#
#
# chain 0:   1%|▏         | 137/10000 [01:03<1:45:53,  1.55it/s]
#
#
# chain 0:   1%|▏         | 138/10000 [01:04<1:43:11,  1.59it/s]
#
# chain 0:   1%|▏         | 139/10000 [01:04<1:31:53,  1.79it/s]
#
#
# chain 0:   1%|▏         | 140/10000 [01:05<1:21:12,  2.02it/s]
#
#
# chain 0:   1%|▏         | 142/10000 [01:05<1:16:08,  2.16it/s]
#
#
# chain 0:   1%|▏         | 143/10000 [01:06<1:13:41,  2.23it/s]
#
#
#
# chain 0:   1%|▏         | 144/10000 [01:07<1:28:51,  1.85it/s]
#
#
#
# chain 0:   1%|▏         | 145/10000 [01:07<1:43:32,  1.59it/s]
#
#
#
#
#
# chain 0:   1%|▏         | 146/10000 [01:08<1:45:47,  1.55it/s]
#
#
# chain 0:   1%|▏         | 147/10000 [01:09<1:43:45,  1.58it/s]
#
#
# chain 0:   1%|▏         | 148/10000 [01:09<1:36:14,  1.71it/s]
# chain 0:   1%|▏         | 149/10000 [01:09<1:18:01,  2.10it/s]
#
# chain 0:   2%|▏         | 150/10000 [01:10<1:02:50,  2.61it/s]
# chain 0:   2%|▏         | 151/10000 [01:10<1:04:50,  2.53it/s]
#
# chain 0:   2%|▏         | 154/10000 [01:11<47:07,  3.48it/s]
#
#
#
# chain 0:   2%|▏         | 155/10000 [01:11<55:08,  2.98it/s]
#
#
# chain 0:   2%|▏         | 156/10000 [01:12<1:04:56,  2.53it/s]
#
#
# chain 0:   2%|▏         | 157/10000 [01:12<1:15:08,  2.18it/s]
#
#
#
# chain 0:   2%|▏         | 158/10000 [01:13<1:34:21,  1.74it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 159/10000 [01:14<1:39:51,  1.64it/s]
# chain 0:   2%|▏         | 161/10000 [01:14<1:06:44,  2.46it/s]
#
#
# chain 0:   2%|▏         | 162/10000 [01:15<57:45,  2.84it/s]
#
#
#
# chain 0:   2%|▏         | 163/10000 [01:15<1:04:02,  2.56it/s]
#
#
#
#
# chain 0:   2%|▏         | 164/10000 [01:16<1:12:15,  2.27it/s]
#
#
#
# chain 0:   2%|▏         | 165/10000 [01:16<1:17:32,  2.11it/s]
# chain 0:   2%|▏         | 166/10000 [01:17<1:31:29,  1.79it/s]
#
# chain 0:   2%|▏         | 167/10000 [01:17<1:25:57,  1.91it/s]
#
#
#
# chain 0:   2%|▏         | 168/10000 [01:18<1:39:37,  1.64it/s]
#
#
#
#
# chain 0:   2%|▏         | 169/10000 [01:19<1:51:44,  1.47it/s]
#
#
# chain 0:   2%|▏         | 170/10000 [01:20<1:55:21,  1.42it/s]
#
#
# chain 0:   2%|▏         | 171/10000 [01:20<1:33:03,  1.76it/s]
#
#
# chain 0:   2%|▏         | 172/10000 [01:21<1:45:38,  1.55it/s]
#
#
#
# chain 0:   2%|▏         | 174/10000 [01:22<1:32:37,  1.77it/s]
#
#
# chain 0:   2%|▏         | 175/10000 [01:23<1:36:27,  1.70it/s]
#
#
# chain 0:   2%|▏         | 177/10000 [01:23<1:25:26,  1.92it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 178/10000 [01:24<1:38:21,  1.66it/s]
#
#
# chain 0:   2%|▏         | 180/10000 [01:25<1:23:52,  1.95it/s]
#
#
#
#
#
#
#
#
# chain 0:   2%|▏         | 181/10000 [01:26<1:32:37,  1.77it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 182/10000 [01:26<1:28:02,  1.86it/s]
#
#
# chain 0:   2%|▏         | 183/10000 [01:27<1:22:52,  1.97it/s]
#
#
#
#
# chain 0:   2%|▏         | 184/10000 [01:27<1:18:04,  2.10it/s]
#
#
# chain 0:   2%|▏         | 185/10000 [01:28<1:18:10,  2.09it/s]
#
#
#
# chain 0:   2%|▏         | 186/10000 [01:28<1:19:43,  2.05it/s]
#
#
#
# chain 0:   2%|▏         | 187/10000 [01:29<1:29:09,  1.83it/s]
#
#
#
#
# chain 0:   2%|▏         | 189/10000 [01:29<1:08:44,  2.38it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 190/10000 [01:30<1:21:16,  2.01it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 191/10000 [01:31<1:37:20,  1.68it/s]
#
#
#
#
#
#
#
#
# chain 0:   2%|▏         | 193/10000 [01:32<1:23:36,  1.95it/s]
#
#
# chain 0:   2%|▏         | 194/10000 [01:32<1:14:50,  2.18it/s]
# chain 0:   2%|▏         | 195/10000 [01:33<1:11:01,  2.30it/s]
#
#
#
#
# chain 0:   2%|▏         | 196/10000 [01:33<1:15:42,  2.16it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 197/10000 [01:34<1:29:47,  1.82it/s]
#
#
#
#
# chain 0:   2%|▏         | 198/10000 [01:34<1:24:29,  1.93it/s]
#
#
# chain 0:   2%|▏         | 199/10000 [01:35<1:16:02,  2.15it/s]
#
#
#
#
# chain 0:   2%|▏         | 200/10000 [01:35<1:14:45,  2.19it/s]
#
# chain 0:   2%|▏         | 202/10000 [01:35<52:33,  3.11it/s]
#
#
# chain 0:   2%|▏         | 203/10000 [01:36<49:28,  3.30it/s]
# chain 0:   2%|▏         | 204/10000 [01:36<50:00,  3.27it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 206/10000 [01:37<49:18,  3.31it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 207/10000 [01:37<55:51,  2.92it/s]
#
# chain 0:   2%|▏         | 208/10000 [01:37<53:08,  3.07it/s]
#
#
#
# chain 0:   2%|▏         | 209/10000 [01:38<56:39,  2.88it/s]
#
#
# chain 0:   2%|▏         | 210/10000 [01:38<55:00,  2.97it/s]
#
#
# chain 0:   2%|▏         | 211/10000 [01:39<1:03:13,  2.58it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 212/10000 [01:40<1:28:58,  1.83it/s]
#
#
#
#
#
#
# chain 0:   2%|▏         | 213/10000 [01:40<1:32:27,  1.76it/s]
#
#
#
# chain 0:   2%|▏         | 214/10000 [01:41<1:26:51,  1.88it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 215/10000 [01:41<1:30:28,  1.80it/s]
# chain 0:   2%|▏         | 216/10000 [01:41<1:17:09,  2.11it/s]
#
# chain 0:   2%|▏         | 217/10000 [01:42<1:05:21,  2.49it/s]
#
#
#
# chain 0:   2%|▏         | 218/10000 [01:42<1:04:11,  2.54it/s]
#
#
#
# chain 0:   2%|▏         | 219/10000 [01:43<1:07:29,  2.42it/s]
#
#
#
#
# chain 0:   2%|▏         | 220/10000 [01:43<1:11:53,  2.27it/s]
# chain 0:   2%|▏         | 222/10000 [01:44<56:09,  2.90it/s]
#
#
# chain 0:   2%|▏         | 223/10000 [01:44<52:08,  3.13it/s]
#
#
# chain 0:   2%|▏         | 225/10000 [01:44<45:30,  3.58it/s]
#
#
#
# chain 0:   2%|▏         | 227/10000 [01:45<38:50,  4.19it/s]
# chain 0:   2%|▏         | 229/10000 [01:45<29:34,  5.51it/s]
#
# chain 0:   2%|▏         | 231/10000 [01:45<26:31,  6.14it/s]
# chain 0:   2%|▏         | 232/10000 [01:45<27:15,  5.97it/s]
#
# chain 0:   2%|▏         | 234/10000 [01:46<33:34,  4.85it/s]
#
#
# chain 0:   2%|▏         | 235/10000 [01:46<33:43,  4.83it/s]
# chain 0:   2%|▏         | 237/10000 [01:46<25:09,  6.47it/s]
#
# chain 0:   2%|▏         | 238/10000 [01:47<27:14,  5.97it/s]
#
#
#
# chain 0:   2%|▏         | 239/10000 [01:47<37:51,  4.30it/s]
# chain 0:   2%|▏         | 240/10000 [01:47<38:28,  4.23it/s]
# chain 0:   2%|▏         | 241/10000 [01:47<37:52,  4.29it/s]
#
#
# chain 0:   2%|▏         | 242/10000 [01:48<45:52,  3.54it/s]
# chain 0:   2%|▏         | 243/10000 [01:48<43:00,  3.78it/s]
#
#
# chain 0:   2%|▏         | 245/10000 [01:49<41:36,  3.91it/s]
#
#
# chain 0:   2%|▏         | 246/10000 [01:49<48:00,  3.39it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 247/10000 [01:49<59:32,  2.73it/s]
#
#
# chain 0:   2%|▏         | 248/10000 [01:50<58:44,  2.77it/s]
#
#
#
#
#
# chain 0:   2%|▏         | 249/10000 [01:51<1:15:04,  2.16it/s]
#
#
# chain 0:   2%|▎         | 250/10000 [01:51<1:16:16,  2.13it/s]
#
#
#
#
# chain 0:   3%|▎         | 251/10000 [01:51<1:14:27,  2.18it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 252/10000 [01:52<1:18:54,  2.06it/s]
# chain 0:   3%|▎         | 253/10000 [01:52<1:09:02,  2.35it/s]
#
#
# chain 0:   3%|▎         | 254/10000 [01:53<1:07:25,  2.41it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 255/10000 [01:53<1:15:03,  2.16it/s]
#
#
#
#
# chain 0:   3%|▎         | 256/10000 [01:54<1:22:06,  1.98it/s]
#
#
#
#
#
#
#
# chain 0:   3%|▎         | 257/10000 [01:55<1:29:21,  1.82it/s]
#
#
# chain 0:   3%|▎         | 258/10000 [01:55<1:23:41,  1.94it/s]
#
#
#
#
# chain 0:   3%|▎         | 259/10000 [01:55<1:24:52,  1.91it/s]
#
# chain 0:   3%|▎         | 260/10000 [01:56<1:10:05,  2.32it/s]
#
#
#
#
# chain 0:   3%|▎         | 261/10000 [01:56<1:04:01,  2.54it/s]
#
#
# chain 0:   3%|▎         | 262/10000 [01:56<1:04:13,  2.53it/s]
#
#
#
#
# chain 0:   3%|▎         | 263/10000 [01:57<1:09:39,  2.33it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 264/10000 [01:57<1:11:27,  2.27it/s]
#
#
#
#
#
#
#
#
# chain 0:   3%|▎         | 265/10000 [01:58<1:23:46,  1.94it/s]
#
#
# chain 0:   3%|▎         | 266/10000 [01:58<1:13:18,  2.21it/s]
#
#
#
# chain 0:   3%|▎         | 267/10000 [01:59<1:03:40,  2.55it/s]
#
#
# chain 0:   3%|▎         | 268/10000 [01:59<1:01:28,  2.64it/s]
#
# chain 0:   3%|▎         | 269/10000 [01:59<55:50,  2.90it/s]
#
#
#
# chain 0:   3%|▎         | 271/10000 [02:00<42:30,  3.81it/s]
#
#
#
# chain 0:   3%|▎         | 272/10000 [02:00<52:27,  3.09it/s]
#
# chain 0:   3%|▎         | 273/10000 [02:01<56:18,  2.88it/s]
#
#
# chain 0:   3%|▎         | 274/10000 [02:01<1:06:20,  2.44it/s]
#
#
#
#
# chain 0:   3%|▎         | 275/10000 [02:02<1:12:04,  2.25it/s]
#
#
# chain 0:   3%|▎         | 276/10000 [02:02<1:04:57,  2.50it/s]
#
#
#
#
# chain 0:   3%|▎         | 277/10000 [02:02<1:10:56,  2.28it/s]
#
#
# chain 0:   3%|▎         | 278/10000 [02:03<1:14:20,  2.18it/s]
# chain 0:   3%|▎         | 279/10000 [02:03<1:05:39,  2.47it/s]
#
#
# chain 0:   3%|▎         | 280/10000 [02:04<1:12:10,  2.24it/s]
#
#
# chain 0:   3%|▎         | 281/10000 [02:04<1:04:21,  2.52it/s]
#
#
# chain 0:   3%|▎         | 282/10000 [02:04<58:07,  2.79it/s]
#
# chain 0:   3%|▎         | 283/10000 [02:05<53:13,  3.04it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 284/10000 [02:05<1:05:28,  2.47it/s]
#
# chain 0:   3%|▎         | 285/10000 [02:06<1:06:56,  2.42it/s]
#
#
# chain 0:   3%|▎         | 286/10000 [02:06<1:05:47,  2.46it/s]
#
#
#
#
# chain 0:   3%|▎         | 287/10000 [02:06<1:09:48,  2.32it/s]
#
#
# chain 0:   3%|▎         | 288/10000 [02:07<1:09:23,  2.33it/s]
#
#
# chain 0:   3%|▎         | 289/10000 [02:07<1:04:37,  2.50it/s]
#
#
#
#
# chain 0:   3%|▎         | 290/10000 [02:08<1:06:27,  2.44it/s]
#
#
#
#
#
#
# chain 0:   3%|▎         | 292/10000 [02:08<1:02:21,  2.59it/s]
#
#
#
# chain 0:   3%|▎         | 293/10000 [02:09<1:04:06,  2.52it/s]
#
#
#
# chain 0:   3%|▎         | 294/10000 [02:09<1:09:37,  2.32it/s]
#
#
#
# chain 0:   3%|▎         | 295/10000 [02:10<1:09:06,  2.34it/s]
# chain 0:   3%|▎         | 296/10000 [02:10<1:05:09,  2.48it/s]
#
# chain 0:   3%|▎         | 297/10000 [02:10<57:01,  2.84it/s]
#
#
#
# chain 0:   3%|▎         | 298/10000 [02:11<1:01:05,  2.65it/s]
# chain 0:   3%|▎         | 299/10000 [02:11<1:03:55,  2.53it/s]
#
#
#
#
#
#
# chain 0:   3%|▎         | 300/10000 [02:12<1:13:46,  2.19it/s]
#
# chain 0:   3%|▎         | 301/10000 [02:12<1:13:43,  2.19it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 302/10000 [02:13<1:15:56,  2.13it/s]
#
#
# chain 0:   3%|▎         | 303/10000 [02:13<1:20:46,  2.00it/s]
#
#
#
#
# chain 0:   3%|▎         | 304/10000 [02:14<1:12:21,  2.23it/s]
#
# chain 0:   3%|▎         | 306/10000 [02:14<53:01,  3.05it/s]
#
#
# chain 0:   3%|▎         | 308/10000 [02:14<41:53,  3.86it/s]
#
#
#
#
#
#
# chain 0:   3%|▎         | 309/10000 [02:15<49:21,  3.27it/s]
#
#
#
# chain 0:   3%|▎         | 310/10000 [02:15<1:02:01,  2.60it/s]
#
#
#
#
# chain 0:   3%|▎         | 311/10000 [02:16<1:06:38,  2.42it/s]
#
#
# chain 0:   3%|▎         | 312/10000 [02:16<1:02:57,  2.56it/s]
#
#
#
#
# chain 0:   3%|▎         | 313/10000 [02:17<1:01:29,  2.63it/s]
#
#
#
# chain 0:   3%|▎         | 314/10000 [02:17<1:09:51,  2.31it/s]
#
# chain 0:   3%|▎         | 315/10000 [02:17<1:03:52,  2.53it/s]
#
#
#
# chain 0:   3%|▎         | 316/10000 [02:18<1:01:32,  2.62it/s]
#
#
# chain 0:   3%|▎         | 317/10000 [02:18<58:30,  2.76it/s]
# chain 0:   3%|▎         | 318/10000 [02:18<51:43,  3.12it/s]
# chain 0:   3%|▎         | 319/10000 [02:19<51:05,  3.16it/s]
#
#
# chain 0:   3%|▎         | 322/10000 [02:19<35:38,  4.52it/s]
#
#
#
#
# chain 0:   3%|▎         | 323/10000 [02:20<42:15,  3.82it/s]
#
#
#
# chain 0:   3%|▎         | 324/10000 [02:20<56:06,  2.87it/s]
#
#
#
#
# chain 0:   3%|▎         | 325/10000 [02:21<1:02:48,  2.57it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 326/10000 [02:21<1:14:57,  2.15it/s]
#
#
# chain 0:   3%|▎         | 327/10000 [02:22<1:08:05,  2.37it/s]
#
#
#
#
#
#
# chain 0:   3%|▎         | 328/10000 [02:22<1:14:51,  2.15it/s]
#
#
# chain 0:   3%|▎         | 329/10000 [02:23<1:10:01,  2.30it/s]
#
#
# chain 0:   3%|▎         | 330/10000 [02:23<1:02:07,  2.59it/s]
#
# chain 0:   3%|▎         | 331/10000 [02:23<55:25,  2.91it/s]
# chain 0:   3%|▎         | 332/10000 [02:23<49:00,  3.29it/s]
#
#
# chain 0:   3%|▎         | 333/10000 [02:23<46:15,  3.48it/s]
# chain 0:   3%|▎         | 334/10000 [02:24<48:59,  3.29it/s]
#
# chain 0:   3%|▎         | 335/10000 [02:24<44:42,  3.60it/s]
#
#
#
#
# chain 0:   3%|▎         | 336/10000 [02:24<51:14,  3.14it/s]
#
#
# chain 0:   3%|▎         | 337/10000 [02:25<55:37,  2.90it/s]
#
#
#
#
#
# chain 0:   3%|▎         | 339/10000 [02:25<47:58,  3.36it/s]
#
#
#
#
# chain 0:   3%|▎         | 340/10000 [02:26<59:30,  2.71it/s]
#
#
#
# chain 0:   3%|▎         | 342/10000 [02:27<56:58,  2.83it/s]
#
#
# chain 0:   3%|▎         | 343/10000 [02:27<56:38,  2.84it/s]
#
#
#
#
# chain 0:   3%|▎         | 345/10000 [02:27<49:23,  3.26it/s]
#
#
# chain 0:   3%|▎         | 346/10000 [02:28<50:14,  3.20it/s]
#
#
# chain 0:   3%|▎         | 347/10000 [02:28<55:43,  2.89it/s]
#
#
# chain 0:   3%|▎         | 348/10000 [02:29<1:01:10,  2.63it/s]
#
#
# chain 0:   4%|▎         | 350/10000 [02:29<53:23,  3.01it/s]
#
#
# chain 0:   4%|▎         | 351/10000 [02:30<49:31,  3.25it/s]
#
#
# chain 0:   4%|▎         | 352/10000 [02:30<49:12,  3.27it/s]
#
#
# chain 0:   4%|▎         | 353/10000 [02:30<1:01:09,  2.63it/s]
#
#
# chain 0:   4%|▎         | 354/10000 [02:31<54:01,  2.98it/s]
#
#
# chain 0:   4%|▎         | 355/10000 [02:31<58:51,  2.73it/s]
#
#
# chain 0:   4%|▎         | 356/10000 [02:31<56:35,  2.84it/s]
#
#
#
#
#
# chain 0:   4%|▎         | 357/10000 [02:32<58:26,  2.75it/s]
#
#
#
#
# chain 0:   4%|▎         | 358/10000 [02:32<1:00:57,  2.64it/s]
#
#
# chain 0:   4%|▎         | 359/10000 [02:33<1:05:41,  2.45it/s]
#
#
#
#
# chain 0:   4%|▎         | 360/10000 [02:33<1:05:21,  2.46it/s]
#
# chain 0:   4%|▎         | 362/10000 [02:33<44:06,  3.64it/s]
# chain 0:   4%|▎         | 363/10000 [02:34<40:29,  3.97it/s]
#
# chain 0:   4%|▎         | 364/10000 [02:34<37:40,  4.26it/s]
# chain 0:   4%|▎         | 365/10000 [02:34<40:48,  3.93it/s]
#
#
# chain 0:   4%|▎         | 366/10000 [02:34<46:03,  3.49it/s]
#
# chain 0:   4%|▎         | 367/10000 [02:35<46:14,  3.47it/s]
#
#
# chain 0:   4%|▎         | 369/10000 [02:35<40:01,  4.01it/s]
#
#
# chain 0:   4%|▎         | 370/10000 [02:35<39:14,  4.09it/s]
#
# chain 0:   4%|▎         | 371/10000 [02:36<43:50,  3.66it/s]
#
#
# chain 0:   4%|▎         | 372/10000 [02:36<46:42,  3.44it/s]
#
#
#
#
# chain 0:   4%|▎         | 373/10000 [02:36<51:50,  3.09it/s]
#
#
# chain 0:   4%|▎         | 374/10000 [02:37<55:14,  2.90it/s]
#
#
#
# chain 0:   4%|▍         | 375/10000 [02:37<51:42,  3.10it/s]
# chain 0:   4%|▍         | 376/10000 [02:37<46:47,  3.43it/s]
#
# chain 0:   4%|▍         | 377/10000 [02:38<45:27,  3.53it/s]
#
#
# chain 0:   4%|▍         | 378/10000 [02:38<47:15,  3.39it/s]
#
#
# chain 0:   4%|▍         | 379/10000 [02:38<48:59,  3.27it/s]
#
#
#
#
#
#
#
# chain 0:   4%|▍         | 380/10000 [02:39<1:04:55,  2.47it/s]
#
#
#
# chain 0:   4%|▍         | 381/10000 [02:39<1:05:41,  2.44it/s]
#
# chain 0:   4%|▍         | 382/10000 [02:40<1:06:04,  2.43it/s]
#
#
# chain 0:   4%|▍         | 383/10000 [02:40<59:18,  2.70it/s]
# chain 0:   4%|▍         | 384/10000 [02:40<52:34,  3.05it/s]
#
#
# chain 0:   4%|▍         | 385/10000 [02:41<50:33,  3.17it/s]
#
#
# chain 0:   4%|▍         | 386/10000 [02:41<56:15,  2.85it/s]
#
#
# chain 0:   4%|▍         | 387/10000 [02:41<1:00:50,  2.63it/s]
#
#
# chain 0:   4%|▍         | 388/10000 [02:42<53:26,  3.00it/s]
#
# chain 0:   4%|▍         | 389/10000 [02:42<45:28,  3.52it/s]
#
#
# chain 0:   4%|▍         | 391/10000 [02:42<35:59,  4.45it/s]
#
# chain 0:   4%|▍         | 392/10000 [02:42<34:02,  4.70it/s]
#
# chain 0:   4%|▍         | 393/10000 [02:42<32:56,  4.86it/s]
#
#
# chain 0:   4%|▍         | 394/10000 [02:43<33:36,  4.76it/s]
#
# chain 0:   4%|▍         | 395/10000 [02:43<38:23,  4.17it/s]
#
#
# chain 0:   4%|▍         | 396/10000 [02:43<37:27,  4.27it/s]
#
# chain 0:   4%|▍         | 397/10000 [02:44<42:30,  3.77it/s]
#
#
#
# chain 0:   4%|▍         | 398/10000 [02:44<43:05,  3.71it/s]
#
#
#
#
# chain 0:   4%|▍         | 399/10000 [02:44<52:08,  3.07it/s]
#
#
#
# chain 0:   4%|▍         | 400/10000 [02:45<1:05:54,  2.43it/s]
#
#
# chain 0:   4%|▍         | 401/10000 [02:45<1:09:04,  2.32it/s]
#
#
#
#
# chain 0:   4%|▍         | 402/10000 [02:46<1:17:01,  2.08it/s]
#
#
# chain 0:   4%|▍         | 403/10000 [02:46<1:14:46,  2.14it/s]
#
#
#
#
# chain 0:   4%|▍         | 404/10000 [02:47<1:13:52,  2.16it/s]
#
#
# chain 0:   4%|▍         | 405/10000 [02:47<1:16:30,  2.09it/s]
#
#
# chain 0:   4%|▍         | 406/10000 [02:48<1:14:03,  2.16it/s]
#
#
#
# chain 0:   4%|▍         | 408/10000 [02:49<1:08:00,  2.35it/s]
#
#
# chain 0:   4%|▍         | 409/10000 [02:49<1:05:04,  2.46it/s]
#
#
#
#
# chain 0:   4%|▍         | 410/10000 [02:49<1:04:39,  2.47it/s]
#
#
# chain 0:   4%|▍         | 411/10000 [02:50<59:15,  2.70it/s]
# chain 0:   4%|▍         | 412/10000 [02:50<50:17,  3.18it/s]
#
# chain 0:   4%|▍         | 413/10000 [02:50<43:15,  3.69it/s]
# chain 0:   4%|▍         | 414/10000 [02:50<40:20,  3.96it/s]
#
# chain 0:   4%|▍         | 415/10000 [02:50<40:57,  3.90it/s]
#
#
# chain 0:   4%|▍         | 416/10000 [02:51<47:32,  3.36it/s]
# chain 0:   4%|▍         | 417/10000 [02:51<41:27,  3.85it/s]
# chain 0:   4%|▍         | 418/10000 [02:51<36:32,  4.37it/s]
#
# chain 0:   4%|▍         | 419/10000 [02:51<35:58,  4.44it/s]
#
#
# chain 0:   4%|▍         | 420/10000 [02:52<38:54,  4.10it/s]
#
#
#
#
#
# chain 0:   4%|▍         | 421/10000 [02:52<55:36,  2.87it/s]
#
# chain 0:   4%|▍         | 422/10000 [02:53<50:27,  3.16it/s]
#
#
# chain 0:   4%|▍         | 424/10000 [02:53<40:52,  3.90it/s]
#
#
# chain 0:   4%|▍         | 425/10000 [02:53<41:44,  3.82it/s]
# chain 0:   4%|▍         | 426/10000 [02:54<45:18,  3.52it/s]
#
#
#
# chain 0:   4%|▍         | 427/10000 [02:54<51:09,  3.12it/s]
#
#
# chain 0:   4%|▍         | 428/10000 [02:54<56:30,  2.82it/s]
#
#
# chain 0:   4%|▍         | 429/10000 [02:55<58:17,  2.74it/s]
#
#
# chain 0:   4%|▍         | 430/10000 [02:55<1:01:56,  2.57it/s]
#
#
#
#
#
# chain 0:   4%|▍         | 431/10000 [02:56<1:03:03,  2.53it/s]
#
#
# chain 0:   4%|▍         | 433/10000 [02:56<45:05,  3.54it/s]
#
#
#
#
# chain 0:   4%|▍         | 434/10000 [02:57<1:02:01,  2.57it/s]
#
#
# chain 0:   4%|▍         | 436/10000 [02:57<48:08,  3.31it/s]
#
#
# chain 0:   4%|▍         | 439/10000 [02:58<34:22,  4.64it/s]
# chain 0:   4%|▍         | 440/10000 [02:58<37:18,  4.27it/s]
#
#
# chain 0:   4%|▍         | 441/10000 [02:58<33:11,  4.80it/s]
#
#
# chain 0:   4%|▍         | 442/10000 [02:58<36:38,  4.35it/s]
#
# chain 0:   4%|▍         | 443/10000 [02:58<35:11,  4.53it/s]
# chain 0:   4%|▍         | 445/10000 [02:59<35:12,  4.52it/s]
#
#
# chain 0:   4%|▍         | 446/10000 [02:59<38:32,  4.13it/s]
# chain 0:   4%|▍         | 447/10000 [02:59<39:13,  4.06it/s]
#
# chain 0:   4%|▍         | 448/10000 [03:00<39:17,  4.05it/s]
#
#
# chain 0:   4%|▍         | 450/10000 [03:00<35:32,  4.48it/s]
#
# chain 0:   5%|▍         | 451/10000 [03:00<33:22,  4.77it/s]
# chain 0:   5%|▍         | 452/10000 [03:00<30:27,  5.23it/s]
#
# chain 0:   5%|▍         | 453/10000 [03:01<42:34,  3.74it/s]
#
#
# chain 0:   5%|▍         | 454/10000 [03:01<41:53,  3.80it/s]
#
# chain 0:   5%|▍         | 455/10000 [03:01<37:56,  4.19it/s]
#
#
# chain 0:   5%|▍         | 458/10000 [03:02<33:47,  4.71it/s]
#
#
# chain 0:   5%|▍         | 460/10000 [03:02<37:51,  4.20it/s]
# chain 0:   5%|▍         | 461/10000 [03:03<43:25,  3.66it/s]
#
#
#
#
# chain 0:   5%|▍         | 462/10000 [03:03<57:56,  2.74it/s]
#
#
# chain 0:   5%|▍         | 464/10000 [03:04<55:27,  2.87it/s]
#
#
# chain 0:   5%|▍         | 465/10000 [03:04<56:09,  2.83it/s]
# chain 0:   5%|▍         | 466/10000 [03:05<49:16,  3.23it/s]
#
#
#
#
#
#
# chain 0:   5%|▍         | 469/10000 [03:06<50:29,  3.15it/s]
#
#
# chain 0:   5%|▍         | 470/10000 [03:06<46:49,  3.39it/s]
#
# chain 0:   5%|▍         | 471/10000 [03:06<54:47,  2.90it/s]
#
#
#
#
# chain 0:   5%|▍         | 472/10000 [03:07<1:02:35,  2.54it/s]
#
#
#
#
#
# chain 0:   5%|▍         | 474/10000 [03:08<1:19:21,  2.00it/s]
#
#
# chain 0:   5%|▍         | 475/10000 [03:09<1:09:46,  2.28it/s]
#
#
# chain 0:   5%|▍         | 476/10000 [03:09<1:02:52,  2.52it/s]
#
#
# chain 0:   5%|▍         | 477/10000 [03:09<1:05:33,  2.42it/s]
#
#
# chain 0:   5%|▍         | 478/10000 [03:10<1:00:40,  2.62it/s]
#
#
# chain 0:   5%|▍         | 480/10000 [03:10<43:40,  3.63it/s]
#
#
# chain 0:   5%|▍         | 482/10000 [03:11<49:54,  3.18it/s]
#
#
#
#
# chain 0:   5%|▍         | 483/10000 [03:11<1:09:37,  2.28it/s]
#
#
#
# chain 0:   5%|▍         | 484/10000 [03:12<1:12:34,  2.19it/s]
#
#
# chain 0:   5%|▍         | 485/10000 [03:12<1:11:14,  2.23it/s]
#
#
# chain 0:   5%|▍         | 487/10000 [03:13<1:22:26,  1.92it/s]
#
#
#
# chain 0:   5%|▍         | 488/10000 [03:14<1:24:41,  1.87it/s]
# chain 0:   5%|▍         | 489/10000 [03:14<1:13:49,  2.15it/s]
#
#
# chain 0:   5%|▍         | 490/10000 [03:15<1:04:26,  2.46it/s]
# chain 0:   5%|▍         | 491/10000 [03:15<1:02:33,  2.53it/s]
#
#
#
# chain 0:   5%|▍         | 492/10000 [03:16<1:16:42,  2.07it/s]
# chain 0:   5%|▍         | 493/10000 [03:16<1:05:23,  2.42it/s]
#
#
# chain 0:   5%|▍         | 494/10000 [03:16<1:05:30,  2.42it/s]
#
# chain 0:   5%|▍         | 495/10000 [03:17<1:01:45,  2.57it/s]
# chain 0:   5%|▍         | 496/10000 [03:17<58:00,  2.73it/s]
#
#
# chain 0:   5%|▍         | 497/10000 [03:17<59:27,  2.66it/s]
#
#
#
# chain 0:   5%|▍         | 498/10000 [03:18<1:03:35,  2.49it/s]
#
#
# chain 0:   5%|▍         | 499/10000 [03:18<1:04:50,  2.44it/s]
#
#
# chain 0:   5%|▌         | 501/10000 [03:19<53:23,  2.97it/s]
#
#
# chain 0:   5%|▌         | 503/10000 [03:19<50:34,  3.13it/s]
#
#
# chain 0:   5%|▌         | 505/10000 [03:20<46:57,  3.37it/s]
#
#
# chain 0:   5%|▌         | 506/10000 [03:20<52:24,  3.02it/s]
#
#
# chain 0:   5%|▌         | 507/10000 [03:21<55:17,  2.86it/s]
# chain 0:   5%|▌         | 508/10000 [03:21<52:00,  3.04it/s]
#
#
# chain 0:   5%|▌         | 510/10000 [03:22<52:16,  3.03it/s]
#
#
# chain 0:   5%|▌         | 511/10000 [03:22<51:56,  3.04it/s]
#
#
#
#
#
# chain 0:   5%|▌         | 512/10000 [03:23<1:03:02,  2.51it/s]
#
# chain 0:   5%|▌         | 513/10000 [03:23<1:08:05,  2.32it/s]
#
# chain 0:   5%|▌         | 514/10000 [03:23<57:18,  2.76it/s]
# chain 0:   5%|▌         | 516/10000 [03:24<41:37,  3.80it/s]
#
#
# chain 0:   5%|▌         | 518/10000 [03:24<41:01,  3.85it/s]
#
#
# chain 0:   5%|▌         | 519/10000 [03:24<46:31,  3.40it/s]
#
#
#
# chain 0:   5%|▌         | 520/10000 [03:25<50:12,  3.15it/s]
#
#
#
# chain 0:   5%|▌         | 521/10000 [03:25<55:58,  2.82it/s]
#
#
# chain 0:   5%|▌         | 522/10000 [03:26<56:41,  2.79it/s]
#
#
# chain 0:   5%|▌         | 525/10000 [03:26<32:49,  4.81it/s]
#
# chain 0:   5%|▌         | 526/10000 [03:26<33:06,  4.77it/s]
#
#
#
# chain 0:   5%|▌         | 528/10000 [03:27<40:59,  3.85it/s]
#
# chain 0:   5%|▌         | 529/10000 [03:27<42:49,  3.69it/s]
# chain 0:   5%|▌         | 532/10000 [03:27<26:19,  6.00it/s]
#
# chain 0:   5%|▌         | 534/10000 [03:28<25:32,  6.18it/s]
#
#
# chain 0:   5%|▌         | 535/10000 [03:28<39:12,  4.02it/s]
#
#
#
# chain 0:   5%|▌         | 536/10000 [03:29<43:56,  3.59it/s]
#
#
#
#
# chain 0:   5%|▌         | 537/10000 [03:29<51:48,  3.04it/s]
#
#
#
#
#
#
#
# chain 0:   5%|▌         | 538/10000 [03:30<1:04:16,  2.45it/s]
#
#
#
# chain 0:   5%|▌         | 539/10000 [03:30<1:03:32,  2.48it/s]
#
#
# chain 0:   5%|▌         | 540/10000 [03:30<1:02:11,  2.54it/s]
#
# chain 0:   5%|▌         | 541/10000 [03:31<1:02:00,  2.54it/s]
#
#
# chain 0:   5%|▌         | 542/10000 [03:31<1:06:08,  2.38it/s]
#
#
# chain 0:   5%|▌         | 543/10000 [03:32<58:47,  2.68it/s]
# chain 0:   5%|▌         | 544/10000 [03:32<54:14,  2.91it/s]
#
# chain 0:   5%|▌         | 546/10000 [03:32<43:02,  3.66it/s]
#
#
# chain 0:   5%|▌         | 547/10000 [03:32<41:20,  3.81it/s]
#
# chain 0:   5%|▌         | 548/10000 [03:33<40:05,  3.93it/s]
# chain 0:   6%|▌         | 550/10000 [03:33<37:42,  4.18it/s]
#
#
# chain 0:   6%|▌         | 551/10000 [03:34<42:34,  3.70it/s]
#
#
#
#
# chain 0:   6%|▌         | 552/10000 [03:34<49:43,  3.17it/s]
#
# chain 0:   6%|▌         | 553/10000 [03:34<55:29,  2.84it/s]
#
#
#
# chain 0:   6%|▌         | 554/10000 [03:35<1:06:09,  2.38it/s]
#
#
#
#
#
#
# chain 0:   6%|▌         | 555/10000 [03:36<1:17:56,  2.02it/s]
#
#
#
#
# chain 0:   6%|▌         | 556/10000 [03:36<1:21:34,  1.93it/s]
# chain 0:   6%|▌         | 557/10000 [03:37<1:12:29,  2.17it/s]
#
#
#
#
#
# chain 0:   6%|▌         | 558/10000 [03:37<1:16:41,  2.05it/s]
# chain 0:   6%|▌         | 559/10000 [03:37<1:04:31,  2.44it/s]
#
#
# chain 0:   6%|▌         | 560/10000 [03:38<1:02:23,  2.52it/s]
#
#
# chain 0:   6%|▌         | 561/10000 [03:38<55:14,  2.85it/s]
#
#
# chain 0:   6%|▌         | 562/10000 [03:38<55:39,  2.83it/s]
#
#
# chain 0:   6%|▌         | 563/10000 [03:39<59:57,  2.62it/s]
#
#
#
#
# chain 0:   6%|▌         | 565/10000 [03:39<51:27,  3.06it/s]
# chain 0:   6%|▌         | 566/10000 [03:39<44:22,  3.54it/s]
#
# chain 0:   6%|▌         | 567/10000 [03:40<36:33,  4.30it/s]
# chain 0:   6%|▌         | 568/10000 [03:40<34:18,  4.58it/s]
#
#
# chain 0:   6%|▌         | 569/10000 [03:40<38:00,  4.14it/s]
# chain 0:   6%|▌         | 572/10000 [03:40<25:59,  6.05it/s]
#
#
# chain 0:   6%|▌         | 573/10000 [03:41<31:06,  5.05it/s]
#
#
#
#
# chain 0:   6%|▌         | 574/10000 [03:41<46:35,  3.37it/s]
#
#
#
#
#
#
#
# chain 0:   6%|▌         | 575/10000 [03:42<57:58,  2.71it/s]
#
#
# chain 0:   6%|▌         | 576/10000 [03:42<1:01:46,  2.54it/s]
#
#
#
# chain 0:   6%|▌         | 577/10000 [03:43<1:09:28,  2.26it/s]
#
#
#
#
# chain 0:   6%|▌         | 578/10000 [03:43<1:07:47,  2.32it/s]
#
#
#
# chain 0:   6%|▌         | 579/10000 [03:44<1:13:43,  2.13it/s]
#
#
#
# chain 0:   6%|▌         | 580/10000 [03:44<1:22:22,  1.91it/s]
#
#
#
# chain 0:   6%|▌         | 581/10000 [03:45<1:15:01,  2.09it/s]
#
#
# chain 0:   6%|▌         | 582/10000 [03:45<1:18:05,  2.01it/s]
#
# chain 0:   6%|▌         | 583/10000 [03:46<1:03:51,  2.46it/s]
#
#
# chain 0:   6%|▌         | 584/10000 [03:46<54:49,  2.86it/s]
#
#
# chain 0:   6%|▌         | 585/10000 [03:46<1:01:19,  2.56it/s]
#
#
#
#
# chain 0:   6%|▌         | 586/10000 [03:47<1:05:07,  2.41it/s]
#
# chain 0:   6%|▌         | 587/10000 [03:47<1:00:40,  2.59it/s]
#
#
# chain 0:   6%|▌         | 589/10000 [03:48<47:55,  3.27it/s]
#
#
# chain 0:   6%|▌         | 590/10000 [03:48<45:02,  3.48it/s]
# chain 0:   6%|▌         | 591/10000 [03:48<47:51,  3.28it/s]
#
# chain 0:   6%|▌         | 592/10000 [03:48<49:43,  3.15it/s]
#
#
# chain 0:   6%|▌         | 593/10000 [03:49<48:01,  3.26it/s]
#
#
#
# chain 0:   6%|▌         | 594/10000 [03:49<59:23,  2.64it/s]
#
#
# chain 0:   6%|▌         | 595/10000 [03:50<59:56,  2.62it/s]
#
#
#
# chain 0:   6%|▌         | 596/10000 [03:50<1:02:21,  2.51it/s]
#
#
#
# chain 0:   6%|▌         | 597/10000 [03:51<1:06:15,  2.37it/s]
#
# chain 0:   6%|▌         | 598/10000 [03:51<1:01:53,  2.53it/s]
#
#
# chain 0:   6%|▌         | 599/10000 [03:51<1:01:50,  2.53it/s]
# chain 0:   6%|▌         | 600/10000 [03:52<57:59,  2.70it/s]
#
#
# chain 0:   6%|▌         | 601/10000 [03:52<1:01:41,  2.54it/s]
#
#
#
# chain 0:   6%|▌         | 602/10000 [03:52<1:02:37,  2.50it/s]
# chain 0:   6%|▌         | 603/10000 [03:53<57:50,  2.71it/s]
#
#
#
# chain 0:   6%|▌         | 604/10000 [03:53<57:58,  2.70it/s]
#
#
# chain 0:   6%|▌         | 605/10000 [03:53<56:45,  2.76it/s]
#
#
#
# chain 0:   6%|▌         | 606/10000 [03:54<56:25,  2.77it/s]
#
#
# chain 0:   6%|▌         | 607/10000 [03:54<55:20,  2.83it/s]
#
#
#
#
# chain 0:   6%|▌         | 608/10000 [03:55<55:03,  2.84it/s]
#
#
# chain 0:   6%|▌         | 610/10000 [03:55<37:33,  4.17it/s]
# chain 0:   6%|▌         | 611/10000 [03:55<42:59,  3.64it/s]
#
#
# chain 0:   6%|▌         | 612/10000 [03:55<46:01,  3.40it/s]
#
#
# chain 0:   6%|▌         | 613/10000 [03:56<56:29,  2.77it/s]
#
#
#
#
# chain 0:   6%|▌         | 614/10000 [03:56<54:22,  2.88it/s]
# chain 0:   6%|▌         | 615/10000 [03:57<49:31,  3.16it/s]
#
#
# chain 0:   6%|▌         | 616/10000 [03:57<49:05,  3.19it/s]
#
#
# chain 0:   6%|▌         | 617/10000 [03:57<50:11,  3.12it/s]
#
#
# chain 0:   6%|▌         | 618/10000 [03:58<55:18,  2.83it/s]
#
#
#
#
#
# chain 0:   6%|▌         | 619/10000 [03:58<56:40,  2.76it/s]
#
#
# chain 0:   6%|▌         | 620/10000 [03:58<1:00:20,  2.59it/s]
# chain 0:   6%|▌         | 621/10000 [03:59<1:02:28,  2.50it/s]
#
#
#
# chain 0:   6%|▌         | 622/10000 [03:59<1:02:58,  2.48it/s]
#
#
# chain 0:   6%|▌         | 623/10000 [04:00<1:01:06,  2.56it/s]
#
#
# chain 0:   6%|▌         | 624/10000 [04:00<1:03:11,  2.47it/s]
#
#
# chain 0:   6%|▋         | 625/10000 [04:00<1:01:01,  2.56it/s]
#
# chain 0:   6%|▋         | 626/10000 [04:01<1:03:23,  2.46it/s]
#
# chain 0:   6%|▋         | 627/10000 [04:01<51:39,  3.02it/s]
# chain 0:   6%|▋         | 628/10000 [04:01<50:47,  3.08it/s]
#
#
#
# chain 0:   6%|▋         | 629/10000 [04:02<55:32,  2.81it/s]
#
# chain 0:   6%|▋         | 630/10000 [04:02<47:30,  3.29it/s]
# chain 0:   6%|▋         | 631/10000 [04:02<50:29,  3.09it/s]
#
#
#
# chain 0:   6%|▋         | 632/10000 [04:03<53:58,  2.89it/s]
# chain 0:   6%|▋         | 633/10000 [04:03<52:02,  3.00it/s]
#
#
# chain 0:   6%|▋         | 634/10000 [04:03<55:26,  2.82it/s]
#
#
#
# chain 0:   6%|▋         | 635/10000 [04:04<1:11:05,  2.20it/s]
#
#
# chain 0:   6%|▋         | 636/10000 [04:04<1:02:26,  2.50it/s]
#
#
#
# chain 0:   6%|▋         | 637/10000 [04:05<1:01:31,  2.54it/s]
# chain 0:   6%|▋         | 638/10000 [04:05<58:54,  2.65it/s]
#
#
# chain 0:   6%|▋         | 639/10000 [04:06<1:00:45,  2.57it/s]
#
#
# chain 0:   6%|▋         | 640/10000 [04:06<59:12,  2.64it/s]
#
#
#
#
# chain 0:   6%|▋         | 641/10000 [04:07<1:24:43,  1.84it/s]
#
# chain 0:   6%|▋         | 643/10000 [04:07<58:02,  2.69it/s]
#
#
# chain 0:   6%|▋         | 645/10000 [04:08<51:17,  3.04it/s]
#
#
# chain 0:   6%|▋         | 646/10000 [04:08<50:16,  3.10it/s]
#
#
#
# chain 0:   6%|▋         | 648/10000 [04:08<37:52,  4.12it/s]
#
#
# chain 0:   6%|▋         | 649/10000 [04:09<48:30,  3.21it/s]
#
#
#
# chain 0:   6%|▋         | 650/10000 [04:09<58:56,  2.64it/s]
#
#
#
# chain 0:   7%|▋         | 651/10000 [04:10<59:40,  2.61it/s]
#
#
# chain 0:   7%|▋         | 652/10000 [04:10<55:23,  2.81it/s]
#
# chain 0:   7%|▋         | 653/10000 [04:10<51:42,  3.01it/s]
#
#
# chain 0:   7%|▋         | 654/10000 [04:11<51:54,  3.00it/s]
# chain 0:   7%|▋         | 655/10000 [04:11<47:38,  3.27it/s]
#
# chain 0:   7%|▋         | 656/10000 [04:11<43:15,  3.60it/s]
# chain 0:   7%|▋         | 658/10000 [04:12<38:01,  4.10it/s]
#
#
#
#
# chain 0:   7%|▋         | 659/10000 [04:12<54:34,  2.85it/s]
#
#
# chain 0:   7%|▋         | 660/10000 [04:13<58:31,  2.66it/s]
#
#
#
# chain 0:   7%|▋         | 661/10000 [04:13<1:01:01,  2.55it/s]
# chain 0:   7%|▋         | 662/10000 [04:13<54:57,  2.83it/s]
#
#
# chain 0:   7%|▋         | 663/10000 [04:14<52:46,  2.95it/s]
#
#
#
#
# chain 0:   7%|▋         | 664/10000 [04:14<57:53,  2.69it/s]
#
#
# chain 0:   7%|▋         | 665/10000 [04:15<1:06:15,  2.35it/s]
#
#
#
#
#
# chain 0:   7%|▋         | 666/10000 [04:15<1:07:26,  2.31it/s]
#
# chain 0:   7%|▋         | 667/10000 [04:15<1:01:28,  2.53it/s]
#
#
#
#
# chain 0:   7%|▋         | 668/10000 [04:16<1:02:52,  2.47it/s]
#
#
#
#
# chain 0:   7%|▋         | 669/10000 [04:16<1:07:06,  2.32it/s]
#
#
# chain 0:   7%|▋         | 670/10000 [04:17<1:07:47,  2.29it/s]
#
#
#
#
#
#
#
# chain 0:   7%|▋         | 672/10000 [04:18<1:00:35,  2.57it/s]
#
#
# chain 0:   7%|▋         | 673/10000 [04:18<1:04:46,  2.40it/s]
#
#
#
# chain 0:   7%|▋         | 674/10000 [04:18<1:05:35,  2.37it/s]
#
#
# chain 0:   7%|▋         | 675/10000 [04:19<1:11:49,  2.16it/s]
#
#
# chain 0:   7%|▋         | 676/10000 [04:19<1:07:06,  2.32it/s]
#
# chain 0:   7%|▋         | 677/10000 [04:20<56:27,  2.75it/s]
#
#
# chain 0:   7%|▋         | 679/10000 [04:20<51:38,  3.01it/s]
#
# chain 0:   7%|▋         | 680/10000 [04:20<48:02,  3.23it/s]
#
#
# chain 0:   7%|▋         | 681/10000 [04:21<48:14,  3.22it/s]
#
#
#
#
# chain 0:   7%|▋         | 684/10000 [04:21<38:08,  4.07it/s]
#
#
# chain 0:   7%|▋         | 685/10000 [04:22<42:16,  3.67it/s]
#
#
# chain 0:   7%|▋         | 686/10000 [04:22<56:32,  2.75it/s]
#
#
# chain 0:   7%|▋         | 687/10000 [04:23<1:05:16,  2.38it/s]
#
#
# chain 0:   7%|▋         | 688/10000 [04:24<1:08:51,  2.25it/s]
#
#
#
# chain 0:   7%|▋         | 689/10000 [04:24<1:00:10,  2.58it/s]
# chain 0:   7%|▋         | 690/10000 [04:24<54:48,  2.83it/s]
#
# chain 0:   7%|▋         | 691/10000 [04:24<46:13,  3.36it/s]
# chain 0:   7%|▋         | 692/10000 [04:24<45:23,  3.42it/s]
#
#
# chain 0:   7%|▋         | 693/10000 [04:25<51:03,  3.04it/s]
#
#
#
#
# chain 0:   7%|▋         | 694/10000 [04:25<1:02:39,  2.48it/s]
#
# chain 0:   7%|▋         | 695/10000 [04:26<56:49,  2.73it/s]
#
# chain 0:   7%|▋         | 696/10000 [04:26<53:43,  2.89it/s]
# chain 0:   7%|▋         | 697/10000 [04:26<50:47,  3.05it/s]
#
#
#
#
# chain 0:   7%|▋         | 699/10000 [04:27<49:16,  3.15it/s]
#
#
#
#
# chain 0:   7%|▋         | 700/10000 [04:27<58:18,  2.66it/s]
#
#
#
# chain 0:   7%|▋         | 701/10000 [04:28<1:00:09,  2.58it/s]
#
#
#
# chain 0:   7%|▋         | 703/10000 [04:29<1:05:50,  2.35it/s]
#
#
# chain 0:   7%|▋         | 704/10000 [04:29<1:00:20,  2.57it/s]
#
#
# chain 0:   7%|▋         | 705/10000 [04:30<1:01:19,  2.53it/s]
#
#
# chain 0:   7%|▋         | 706/10000 [04:30<1:05:25,  2.37it/s]
#
#
# chain 0:   7%|▋         | 707/10000 [04:31<1:04:27,  2.40it/s]
#
#
# chain 0:   7%|▋         | 709/10000 [04:31<57:02,  2.71it/s]
#
#
#
# chain 0:   7%|▋         | 710/10000 [04:32<59:44,  2.59it/s]
#
#
#
# chain 0:   7%|▋         | 711/10000 [04:32<1:03:31,  2.44it/s]
#
#
#
# chain 0:   7%|▋         | 712/10000 [04:33<1:03:45,  2.43it/s]
#
#
# chain 0:   7%|▋         | 713/10000 [04:33<1:11:20,  2.17it/s]
#
#
#
#
# chain 0:   7%|▋         | 714/10000 [04:34<1:21:30,  1.90it/s]
#
#
#
# chain 0:   7%|▋         | 715/10000 [04:34<1:29:28,  1.73it/s]
#
#
# chain 0:   7%|▋         | 716/10000 [04:35<1:30:18,  1.71it/s]
#
#
#
#
#
# chain 0:   7%|▋         | 717/10000 [04:36<1:33:19,  1.66it/s]
# chain 0:   7%|▋         | 718/10000 [04:36<1:35:11,  1.63it/s]
#
#
#
# chain 0:   7%|▋         | 719/10000 [04:37<1:26:49,  1.78it/s]
#
#
# chain 0:   7%|▋         | 720/10000 [04:37<1:22:28,  1.88it/s]
# chain 0:   7%|▋         | 721/10000 [04:38<1:10:02,  2.21it/s]
#
#
# chain 0:   7%|▋         | 723/10000 [04:38<48:38,  3.18it/s]
#
# chain 0:   7%|▋         | 725/10000 [04:38<42:17,  3.66it/s]
#
#
#
# chain 0:   7%|▋         | 726/10000 [04:39<53:24,  2.89it/s]
#
#
#
# chain 0:   7%|▋         | 727/10000 [04:39<1:04:21,  2.40it/s]
#
#
#
#
#
#
# chain 0:   7%|▋         | 729/10000 [04:40<53:41,  2.88it/s]
#
# chain 0:   7%|▋         | 730/10000 [04:40<53:24,  2.89it/s]
#
#
#
#
# chain 0:   7%|▋         | 731/10000 [04:41<53:49,  2.87it/s]
# chain 0:   7%|▋         | 732/10000 [04:41<59:18,  2.60it/s]
#
#
# chain 0:   7%|▋         | 733/10000 [04:42<59:44,  2.59it/s]
# chain 0:   7%|▋         | 734/10000 [04:42<57:09,  2.70it/s]
#
#
#
# chain 0:   7%|▋         | 735/10000 [04:42<57:20,  2.69it/s]
#
#
# chain 0:   7%|▋         | 736/10000 [04:43<57:30,  2.68it/s]
# chain 0:   7%|▋         | 738/10000 [04:43<50:51,  3.03it/s]
#
#
#
# chain 0:   7%|▋         | 739/10000 [04:44<54:29,  2.83it/s]
#
#
#
#
# chain 0:   7%|▋         | 740/10000 [04:44<1:04:49,  2.38it/s]
#
#
# chain 0:   7%|▋         | 741/10000 [04:45<1:07:50,  2.27it/s]
#
#
#
#
# chain 0:   7%|▋         | 742/10000 [04:45<1:11:06,  2.17it/s]
#
#
# chain 0:   7%|▋         | 743/10000 [04:46<1:10:06,  2.20it/s]
# chain 0:   7%|▋         | 745/10000 [04:46<54:24,  2.84it/s]
#
#
# chain 0:   7%|▋         | 746/10000 [04:47<1:00:11,  2.56it/s]
#
#
#
#
# chain 0:   7%|▋         | 748/10000 [04:47<50:19,  3.06it/s]
#
#
#
# chain 0:   8%|▊         | 750/10000 [04:48<46:25,  3.32it/s]
#
#
#
# chain 0:   8%|▊         | 751/10000 [04:48<1:04:29,  2.39it/s]
#
#
# chain 0:   8%|▊         | 752/10000 [04:49<1:17:58,  1.98it/s]
#
# chain 0:   8%|▊         | 753/10000 [04:50<1:12:26,  2.13it/s]
# chain 0:   8%|▊         | 754/10000 [04:50<1:02:17,  2.47it/s]
#
# chain 0:   8%|▊         | 755/10000 [04:50<54:17,  2.84it/s]
#
# chain 0:   8%|▊         | 756/10000 [04:50<51:18,  3.00it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 757/10000 [04:51<1:01:09,  2.52it/s]
#
#
# chain 0:   8%|▊         | 758/10000 [04:52<1:14:12,  2.08it/s]
#
#
# chain 0:   8%|▊         | 759/10000 [04:52<1:14:01,  2.08it/s]
#
#
#
#
# chain 0:   8%|▊         | 760/10000 [04:53<1:18:35,  1.96it/s]
#
#
# chain 0:   8%|▊         | 761/10000 [04:53<1:15:42,  2.03it/s]
# chain 0:   8%|▊         | 762/10000 [04:53<1:05:04,  2.37it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 763/10000 [04:54<1:09:04,  2.23it/s]
#
#
#
#
#
#
#
# chain 0:   8%|▊         | 764/10000 [04:54<1:17:05,  2.00it/s]
# chain 0:   8%|▊         | 766/10000 [04:55<53:55,  2.85it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 767/10000 [04:56<1:08:35,  2.24it/s]
#
#
# chain 0:   8%|▊         | 768/10000 [04:56<1:16:47,  2.00it/s]
#
# chain 0:   8%|▊         | 770/10000 [04:57<1:00:45,  2.53it/s]
#
#
#
# chain 0:   8%|▊         | 772/10000 [04:57<51:50,  2.97it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 773/10000 [04:58<57:57,  2.65it/s]
#
#
# chain 0:   8%|▊         | 774/10000 [04:58<1:02:36,  2.46it/s]
# chain 0:   8%|▊         | 775/10000 [04:59<58:52,  2.61it/s]
#
#
# chain 0:   8%|▊         | 777/10000 [04:59<51:19,  2.99it/s]
#
# chain 0:   8%|▊         | 778/10000 [05:00<51:23,  2.99it/s]
#
#
#
#
#
#
#
#
# chain 0:   8%|▊         | 779/10000 [05:00<1:13:14,  2.10it/s]
#
#
#
#
# chain 0:   8%|▊         | 781/10000 [05:01<1:00:26,  2.54it/s]
#
#
#
# chain 0:   8%|▊         | 782/10000 [05:02<1:08:28,  2.24it/s]
#
#
#
# chain 0:   8%|▊         | 783/10000 [05:02<1:05:53,  2.33it/s]
#
#
#
#
# chain 0:   8%|▊         | 784/10000 [05:02<1:09:02,  2.22it/s]
#
#
# chain 0:   8%|▊         | 785/10000 [05:03<1:15:07,  2.04it/s]
#
#
# chain 0:   8%|▊         | 786/10000 [05:04<1:20:17,  1.91it/s]
#
#
# chain 0:   8%|▊         | 787/10000 [05:04<1:20:19,  1.91it/s]
#
#
# chain 0:   8%|▊         | 788/10000 [05:04<1:10:21,  2.18it/s]
#
#
# chain 0:   8%|▊         | 789/10000 [05:05<1:09:58,  2.19it/s]
#
#
#
# chain 0:   8%|▊         | 791/10000 [05:06<1:01:02,  2.51it/s]
#
#
#
# chain 0:   8%|▊         | 792/10000 [05:06<1:11:56,  2.13it/s]
# chain 0:   8%|▊         | 793/10000 [05:07<1:14:48,  2.05it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 794/10000 [05:08<1:24:02,  1.83it/s]
#
#
# chain 0:   8%|▊         | 795/10000 [05:08<1:22:15,  1.87it/s]
#
#
#
#
#
# chain 0:   8%|▊         | 796/10000 [05:09<1:26:10,  1.78it/s]
#
#
#
#
#
#
#
# chain 0:   8%|▊         | 797/10000 [05:10<1:40:21,  1.53it/s]
#
#
#
#
# chain 0:   8%|▊         | 798/10000 [05:10<1:48:52,  1.41it/s]
#
#
#
#
# chain 0:   8%|▊         | 799/10000 [05:11<1:50:18,  1.39it/s]
#
#
# chain 0:   8%|▊         | 800/10000 [05:12<1:46:25,  1.44it/s]
# chain 0:   8%|▊         | 801/10000 [05:12<1:32:08,  1.66it/s]
#
#
# chain 0:   8%|▊         | 803/10000 [05:13<1:04:50,  2.36it/s]
#
#
# chain 0:   8%|▊         | 804/10000 [05:13<57:33,  2.66it/s]
#
#
#
#
# chain 0:   8%|▊         | 805/10000 [05:13<1:05:42,  2.33it/s]
#
#
#
# chain 0:   8%|▊         | 806/10000 [05:14<1:04:06,  2.39it/s]
#
#
# chain 0:   8%|▊         | 807/10000 [05:14<1:06:12,  2.31it/s]
#
#
# chain 0:   8%|▊         | 808/10000 [05:15<1:02:45,  2.44it/s]
#
#
# chain 0:   8%|▊         | 809/10000 [05:15<1:14:28,  2.06it/s]
#
#
#
# chain 0:   8%|▊         | 810/10000 [05:16<1:11:30,  2.14it/s]
# chain 0:   8%|▊         | 812/10000 [05:16<53:16,  2.87it/s]
#
#
#
# chain 0:   8%|▊         | 813/10000 [05:17<1:01:21,  2.50it/s]
# chain 0:   8%|▊         | 815/10000 [05:17<48:53,  3.13it/s]
#
#
# chain 0:   8%|▊         | 816/10000 [05:17<48:27,  3.16it/s]
# chain 0:   8%|▊         | 817/10000 [05:18<44:28,  3.44it/s]
#
#
#
# chain 0:   8%|▊         | 818/10000 [05:18<52:55,  2.89it/s]
#
# chain 0:   8%|▊         | 819/10000 [05:19<1:06:31,  2.30it/s]
#
#
#
#
# chain 0:   8%|▊         | 820/10000 [05:19<1:07:24,  2.27it/s]
#
# chain 0:   8%|▊         | 821/10000 [05:20<1:04:26,  2.37it/s]
#
#
#
#
#
#
# ...
#
# chain 0:  97%|█████████▋| 9668/10000 [1:10:39<02:33,  2.16it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9669/10000 [1:10:40<02:38,  2.09it/s]
#
#
#
# chain 0:  97%|█████████▋| 9670/10000 [1:10:40<02:45,  1.99it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9671/10000 [1:10:41<02:56,  1.86it/s]
# chain 0:  97%|█████████▋| 9672/10000 [1:10:41<02:43,  2.00it/s]
#
#
# chain 0:  97%|█████████▋| 9673/10000 [1:10:42<02:38,  2.07it/s]
# chain 0:  97%|█████████▋| 9674/10000 [1:10:42<02:21,  2.31it/s]
#
# chain 0:  97%|█████████▋| 9675/10000 [1:10:42<02:06,  2.56it/s]
#
#
#
# chain 0:  97%|█████████▋| 9676/10000 [1:10:43<02:09,  2.51it/s]
#
#
# chain 0:  97%|█████████▋| 9677/10000 [1:10:43<02:12,  2.43it/s]
#
# chain 0:  97%|█████████▋| 9678/10000 [1:10:43<01:53,  2.85it/s]
# chain 0:  97%|█████████▋| 9679/10000 [1:10:44<01:54,  2.80it/s]
#
#
#
#
# chain 0:  97%|█████████▋| 9680/10000 [1:10:44<02:13,  2.39it/s]
#
# chain 0:  97%|█████████▋| 9681/10000 [1:10:45<01:55,  2.76it/s]
# chain 0:  97%|█████████▋| 9683/10000 [1:10:45<01:19,  3.97it/s]
#
# chain 0:  97%|█████████▋| 9685/10000 [1:10:45<01:15,  4.15it/s]
#
#
#
# chain 0:  97%|█████████▋| 9686/10000 [1:10:46<01:37,  3.23it/s]
#
# chain 0:  97%|█████████▋| 9687/10000 [1:10:46<01:59,  2.62it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9688/10000 [1:10:47<02:36,  2.00it/s]
# chain 0:  97%|█████████▋| 9689/10000 [1:10:47<02:12,  2.35it/s]
#
# chain 0:  97%|█████████▋| 9690/10000 [1:10:48<02:01,  2.55it/s]
#
#
#
#
# chain 0:  97%|█████████▋| 9692/10000 [1:10:48<01:47,  2.87it/s]
#
#
# chain 0:  97%|█████████▋| 9693/10000 [1:10:48<01:35,  3.22it/s]
#
# chain 0:  97%|█████████▋| 9694/10000 [1:10:49<01:35,  3.19it/s]
#
# chain 0:  97%|█████████▋| 9695/10000 [1:10:49<01:33,  3.26it/s]
#
#
# chain 0:  97%|█████████▋| 9697/10000 [1:10:50<01:28,  3.43it/s]
# chain 0:  97%|█████████▋| 9698/10000 [1:10:50<01:18,  3.85it/s]
#
#
# chain 0:  97%|█████████▋| 9699/10000 [1:10:50<01:44,  2.88it/s]
#
#
# chain 0:  97%|█████████▋| 9700/10000 [1:10:51<02:00,  2.48it/s]
#
# chain 0:  97%|█████████▋| 9701/10000 [1:10:51<02:01,  2.45it/s]
#
#
# chain 0:  97%|█████████▋| 9702/10000 [1:10:52<02:13,  2.24it/s]
#
#
#
#
# chain 0:  97%|█████████▋| 9705/10000 [1:10:53<01:29,  3.28it/s]
# chain 0:  97%|█████████▋| 9706/10000 [1:10:53<01:18,  3.73it/s]
#
# chain 0:  97%|█████████▋| 9708/10000 [1:10:53<01:11,  4.06it/s]
#
#
# chain 0:  97%|█████████▋| 9709/10000 [1:10:54<01:42,  2.85it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9710/10000 [1:10:55<02:20,  2.07it/s]
#
#
# chain 0:  97%|█████████▋| 9713/10000 [1:10:55<01:27,  3.29it/s]
#
#
# chain 0:  97%|█████████▋| 9715/10000 [1:10:56<01:14,  3.85it/s]
#
# chain 0:  97%|█████████▋| 9716/10000 [1:10:56<01:09,  4.10it/s]
# chain 0:  97%|█████████▋| 9717/10000 [1:10:56<01:14,  3.80it/s]
#
#
#
# chain 0:  97%|█████████▋| 9718/10000 [1:10:57<01:18,  3.57it/s]
#
#
# chain 0:  97%|█████████▋| 9719/10000 [1:10:57<01:25,  3.28it/s]
#
#
# chain 0:  97%|█████████▋| 9720/10000 [1:10:57<01:43,  2.70it/s]
#
# chain 0:  97%|█████████▋| 9721/10000 [1:10:58<01:40,  2.77it/s]
# chain 0:  97%|█████████▋| 9722/10000 [1:10:58<01:30,  3.06it/s]
#
#
# chain 0:  97%|█████████▋| 9723/10000 [1:10:59<01:43,  2.68it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9725/10000 [1:11:00<01:54,  2.41it/s]
# chain 0:  97%|█████████▋| 9726/10000 [1:11:00<01:43,  2.65it/s]
#
# chain 0:  97%|█████████▋| 9728/10000 [1:11:00<01:25,  3.19it/s]
# chain 0:  97%|█████████▋| 9729/10000 [1:11:01<01:26,  3.12it/s]
#
# chain 0:  97%|█████████▋| 9730/10000 [1:11:01<01:26,  3.12it/s]
#
#
# chain 0:  97%|█████████▋| 9732/10000 [1:11:01<01:17,  3.45it/s]
#
#
# chain 0:  97%|█████████▋| 9733/10000 [1:11:02<01:17,  3.46it/s]
# chain 0:  97%|█████████▋| 9734/10000 [1:11:02<01:30,  2.94it/s]
#
#
#
#
#
# chain 0:  97%|█████████▋| 9735/10000 [1:11:03<02:10,  2.03it/s]
#
#
# chain 0:  97%|█████████▋| 9736/10000 [1:11:04<02:21,  1.87it/s]
#
# chain 0:  97%|█████████▋| 9737/10000 [1:11:04<02:07,  2.06it/s]
#
#
# chain 0:  97%|█████████▋| 9738/10000 [1:11:04<01:52,  2.32it/s]
#
#
# chain 0:  97%|█████████▋| 9740/10000 [1:11:05<01:41,  2.57it/s]
#
#
# chain 0:  97%|█████████▋| 9741/10000 [1:11:05<01:38,  2.62it/s]
#
#
# chain 0:  97%|█████████▋| 9742/10000 [1:11:06<01:35,  2.71it/s]
#
#
# chain 0:  97%|█████████▋| 9743/10000 [1:11:06<01:41,  2.53it/s]
# chain 0:  97%|█████████▋| 9744/10000 [1:11:07<01:34,  2.71it/s]
# chain 0:  97%|█████████▋| 9745/10000 [1:11:07<01:33,  2.72it/s]
#
# chain 0:  97%|█████████▋| 9747/10000 [1:11:07<01:13,  3.46it/s]
#
#
#
#
# chain 0:  97%|█████████▋| 9748/10000 [1:11:08<01:29,  2.83it/s]
#
#
#
# chain 0:  97%|█████████▋| 9749/10000 [1:11:09<01:51,  2.24it/s]
#
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9750/10000 [1:11:09<02:21,  1.76it/s]
# chain 0:  98%|█████████▊| 9751/10000 [1:11:10<02:04,  2.01it/s]
#
# chain 0:  98%|█████████▊| 9752/10000 [1:11:10<01:47,  2.30it/s]
#
# chain 0:  98%|█████████▊| 9753/10000 [1:11:10<01:39,  2.49it/s]
# chain 0:  98%|█████████▊| 9754/10000 [1:11:11<01:26,  2.83it/s]
#
# chain 0:  98%|█████████▊| 9755/10000 [1:11:11<01:27,  2.80it/s]
#
#
# chain 0:  98%|█████████▊| 9756/10000 [1:11:11<01:29,  2.74it/s]
#
# chain 0:  98%|█████████▊| 9757/10000 [1:11:12<01:26,  2.80it/s]
#
#
# chain 0:  98%|█████████▊| 9759/10000 [1:11:12<01:12,  3.33it/s]
#
#
#
#
# chain 0:  98%|█████████▊| 9760/10000 [1:11:13<01:18,  3.04it/s]
#
#
#
#
# chain 0:  98%|█████████▊| 9761/10000 [1:11:13<01:55,  2.06it/s]
#
#
# chain 0:  98%|█████████▊| 9762/10000 [1:11:14<02:01,  1.97it/s]
#
#
# chain 0:  98%|█████████▊| 9763/10000 [1:11:14<01:55,  2.05it/s]
#
# chain 0:  98%|█████████▊| 9765/10000 [1:11:15<01:23,  2.81it/s]
#
#
#
#
# chain 0:  98%|█████████▊| 9766/10000 [1:11:16<01:46,  2.19it/s]
#
#
# chain 0:  98%|█████████▊| 9767/10000 [1:11:16<01:42,  2.27it/s]
#
#
# chain 0:  98%|█████████▊| 9768/10000 [1:11:17<01:58,  1.96it/s]
#
#
# chain 0:  98%|█████████▊| 9769/10000 [1:11:17<01:54,  2.02it/s]
#
#
#
# chain 0:  98%|█████████▊| 9770/10000 [1:11:18<02:02,  1.88it/s]
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9771/10000 [1:11:19<02:30,  1.52it/s]
#
#
# chain 0:  98%|█████████▊| 9772/10000 [1:11:19<02:10,  1.74it/s]
#
#
#
# chain 0:  98%|█████████▊| 9773/10000 [1:11:20<02:27,  1.54it/s]
#
#
#
#
# chain 0:  98%|█████████▊| 9774/10000 [1:11:21<02:30,  1.51it/s]
#
#
#
#
#
# chain 0:  98%|█████████▊| 9776/10000 [1:11:21<01:48,  2.06it/s]
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9777/10000 [1:11:22<01:50,  2.02it/s]
#
#
# chain 0:  98%|█████████▊| 9778/10000 [1:11:22<01:42,  2.18it/s]
# chain 0:  98%|█████████▊| 9779/10000 [1:11:23<02:02,  1.80it/s]
#
#
#
# chain 0:  98%|█████████▊| 9780/10000 [1:11:24<02:14,  1.64it/s]
#
#
#
# chain 0:  98%|█████████▊| 9781/10000 [1:11:24<02:12,  1.65it/s]
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9782/10000 [1:11:25<02:36,  1.39it/s]
#
#
#
# chain 0:  98%|█████████▊| 9785/10000 [1:11:26<01:41,  2.12it/s]
#
#
#
#
#
# chain 0:  98%|█████████▊| 9786/10000 [1:11:27<02:04,  1.71it/s]
#
#
# chain 0:  98%|█████████▊| 9787/10000 [1:11:28<01:54,  1.86it/s]
#
# chain 0:  98%|█████████▊| 9788/10000 [1:11:28<01:40,  2.11it/s]
#
#
#
# chain 0:  98%|█████████▊| 9789/10000 [1:11:29<01:48,  1.94it/s]
# chain 0:  98%|█████████▊| 9790/10000 [1:11:29<01:36,  2.18it/s]
#
# chain 0:  98%|█████████▊| 9792/10000 [1:11:29<01:16,  2.71it/s]
# chain 0:  98%|█████████▊| 9793/10000 [1:11:30<01:13,  2.83it/s]
#
# chain 0:  98%|█████████▊| 9794/10000 [1:11:30<01:25,  2.42it/s]
#
#
# chain 0:  98%|█████████▊| 9795/10000 [1:11:31<01:18,  2.60it/s]
# chain 0:  98%|█████████▊| 9796/10000 [1:11:31<01:15,  2.68it/s]
#
#
# chain 0:  98%|█████████▊| 9797/10000 [1:11:31<01:23,  2.44it/s]
# chain 0:  98%|█████████▊| 9800/10000 [1:11:32<00:52,  3.79it/s]
#
#
# chain 0:  98%|█████████▊| 9801/10000 [1:11:32<00:46,  4.24it/s]
# chain 0:  98%|█████████▊| 9802/10000 [1:11:32<00:47,  4.17it/s]
#
#
# chain 0:  98%|█████████▊| 9803/10000 [1:11:33<01:02,  3.16it/s]
# chain 0:  98%|█████████▊| 9804/10000 [1:11:33<01:07,  2.90it/s]
#
#
# chain 1: 100%|██████████| 10000/10000 [1:11:34<00:00,  2.33it/s]
#
# chain 0:  98%|█████████▊| 9805/10000 [1:11:34<01:48,  1.80it/s]
#
#
# chain 0:  98%|█████████▊| 9807/10000 [1:11:35<01:12,  2.68it/s]
# chain 0:  98%|█████████▊| 9809/10000 [1:11:35<00:56,  3.38it/s]
#
#
# chain 0:  98%|█████████▊| 9810/10000 [1:11:35<00:50,  3.78it/s]
# chain 0:  98%|█████████▊| 9811/10000 [1:11:35<00:43,  4.35it/s]
# chain 0:  98%|█████████▊| 9812/10000 [1:11:36<00:45,  4.13it/s]
#
#
# chain 0:  98%|█████████▊| 9814/10000 [1:11:36<00:41,  4.48it/s]
# chain 2: 100%|██████████| 10000/10000 [1:11:36<00:00,  2.33it/s]
# chain 0:  98%|█████████▊| 9815/10000 [1:11:36<00:37,  4.91it/s]
#
# chain 0:  98%|█████████▊| 9816/10000 [1:11:37<00:38,  4.80it/s]
#
# chain 0:  98%|█████████▊| 9817/10000 [1:11:37<00:45,  4.04it/s]
#
# chain 0:  98%|█████████▊| 9818/10000 [1:11:37<00:39,  4.64it/s]
#
# chain 0:  98%|█████████▊| 9820/10000 [1:11:37<00:34,  5.27it/s]
#
# chain 0:  98%|█████████▊| 9821/10000 [1:11:38<00:42,  4.18it/s]
#
#
#
# chain 0:  98%|█████████▊| 9822/10000 [1:11:38<00:55,  3.20it/s]
#
#
#
#
#
# chain 0:  98%|█████████▊| 9823/10000 [1:11:39<00:58,  3.04it/s]
#
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9824/10000 [1:11:39<01:10,  2.49it/s]
#
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9825/10000 [1:11:40<01:22,  2.12it/s]
#
# chain 0:  98%|█████████▊| 9826/10000 [1:11:40<01:18,  2.22it/s]
#
#
#
# chain 0:  98%|█████████▊| 9827/10000 [1:11:40<01:05,  2.62it/s]
#
# chain 0:  98%|█████████▊| 9828/10000 [1:11:41<00:58,  2.93it/s]
#
# chain 0:  98%|█████████▊| 9830/10000 [1:11:41<00:40,  4.19it/s]
#
# chain 0:  98%|█████████▊| 9832/10000 [1:11:41<00:34,  4.83it/s]
#
# chain 0:  98%|█████████▊| 9835/10000 [1:11:42<00:32,  5.14it/s]
#
# chain 0:  98%|█████████▊| 9837/10000 [1:11:42<00:25,  6.30it/s]
#
# chain 0:  98%|█████████▊| 9838/10000 [1:11:42<00:24,  6.57it/s]
#
# chain 0:  98%|█████████▊| 9839/10000 [1:11:42<00:23,  6.95it/s]
#
# chain 0:  98%|█████████▊| 9841/10000 [1:11:43<00:25,  6.34it/s]
#
# chain 0:  98%|█████████▊| 9843/10000 [1:11:43<00:25,  6.08it/s]
#
# chain 0:  98%|█████████▊| 9844/10000 [1:11:43<00:29,  5.31it/s]
#
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9845/10000 [1:11:44<00:42,  3.64it/s]
#
#
#
# chain 0:  98%|█████████▊| 9846/10000 [1:11:44<00:43,  3.53it/s]
#
#
#
#
#
#
#
# chain 0:  98%|█████████▊| 9849/10000 [1:11:45<00:34,  4.37it/s]
#
#
#
#
#
# chain 0:  98%|█████████▊| 9850/10000 [1:11:45<00:43,  3.47it/s]
#
#
#
# chain 0:  99%|█████████▊| 9853/10000 [1:11:46<00:37,  3.89it/s]
#
# chain 0:  99%|█████████▊| 9855/10000 [1:11:46<00:28,  5.07it/s]
#
# chain 0:  99%|█████████▊| 9858/10000 [1:11:47<00:23,  6.00it/s]
#
# chain 0:  99%|█████████▊| 9860/10000 [1:11:47<00:28,  4.89it/s]
#
# chain 0:  99%|█████████▊| 9862/10000 [1:11:48<00:28,  4.89it/s]
#
# chain 0:  99%|█████████▊| 9863/10000 [1:11:48<00:27,  4.94it/s]
#
#
#
# chain 0:  99%|█████████▊| 9865/10000 [1:11:48<00:25,  5.40it/s]
#
#
#
# chain 0:  99%|█████████▊| 9866/10000 [1:11:49<00:34,  3.88it/s]
#
# chain 0:  99%|█████████▊| 9868/10000 [1:11:49<00:31,  4.20it/s]
#
# chain 0:  99%|█████████▊| 9871/10000 [1:11:49<00:19,  6.58it/s]
#
# chain 0:  99%|█████████▊| 9873/10000 [1:11:50<00:30,  4.11it/s]
#
#
#
#
#
# chain 0:  99%|█████████▊| 9874/10000 [1:11:50<00:38,  3.23it/s]
#
# chain 0:  99%|█████████▉| 9875/10000 [1:11:51<00:41,  3.01it/s]
#
#
#
# chain 0:  99%|█████████▉| 9876/10000 [1:11:51<00:43,  2.88it/s]
#
# chain 0:  99%|█████████▉| 9877/10000 [1:11:51<00:40,  3.03it/s]
#
# chain 0:  99%|█████████▉| 9879/10000 [1:11:52<00:32,  3.69it/s]
#
# chain 0:  99%|█████████▉| 9882/10000 [1:11:52<00:24,  4.90it/s]
#
# chain 0:  99%|█████████▉| 9883/10000 [1:11:53<00:21,  5.39it/s]
#
# chain 0:  99%|█████████▉| 9884/10000 [1:11:53<00:30,  3.81it/s]
#
#
#
# chain 0:  99%|█████████▉| 9885/10000 [1:11:53<00:36,  3.12it/s]
#
#
#
# chain 0:  99%|█████████▉| 9886/10000 [1:11:54<00:40,  2.79it/s]
#
# chain 0:  99%|█████████▉| 9887/10000 [1:11:54<00:36,  3.10it/s]
#
#
#
#
#
# chain 0:  99%|█████████▉| 9888/10000 [1:11:54<00:36,  3.08it/s]
#
# chain 0:  99%|█████████▉| 9889/10000 [1:11:55<00:37,  2.98it/s]
#
# chain 0:  99%|█████████▉| 9891/10000 [1:11:55<00:26,  4.13it/s]
#
# chain 0:  99%|█████████▉| 9892/10000 [1:11:55<00:22,  4.71it/s]
#
# chain 0:  99%|█████████▉| 9893/10000 [1:11:56<00:32,  3.27it/s]
#
#
#
#
#
# chain 0:  99%|█████████▉| 9894/10000 [1:11:56<00:39,  2.67it/s]
#
#
#
#
#
# chain 0:  99%|█████████▉| 9895/10000 [1:11:57<00:39,  2.63it/s]
#
#
#
#
#
# chain 0:  99%|█████████▉| 9896/10000 [1:11:57<00:43,  2.41it/s]
#
#
#
# chain 0:  99%|█████████▉| 9897/10000 [1:11:58<00:37,  2.74it/s]
#
# chain 0:  99%|█████████▉| 9898/10000 [1:11:58<00:33,  3.09it/s]
#
#
#
# chain 0:  99%|█████████▉| 9899/10000 [1:11:58<00:29,  3.46it/s]
#
#
#
# chain 0:  99%|█████████▉| 9900/10000 [1:11:58<00:28,  3.47it/s]
#
# chain 0:  99%|█████████▉| 9901/10000 [1:11:58<00:25,  3.83it/s]
#
# chain 0:  99%|█████████▉| 9902/10000 [1:11:59<00:24,  3.93it/s]
#
# chain 0:  99%|█████████▉| 9903/10000 [1:11:59<00:26,  3.63it/s]
#
#
#
# chain 0:  99%|█████████▉| 9905/10000 [1:11:59<00:20,  4.70it/s]
#
# chain 0:  99%|█████████▉| 9906/10000 [1:12:00<00:23,  4.06it/s]
#
# chain 0:  99%|█████████▉| 9908/10000 [1:12:00<00:21,  4.26it/s]
#
# chain 0:  99%|█████████▉| 9909/10000 [1:12:00<00:20,  4.49it/s]
#
# chain 0:  99%|█████████▉| 9910/10000 [1:12:01<00:21,  4.17it/s]
#
# chain 0:  99%|█████████▉| 9911/10000 [1:12:01<00:24,  3.57it/s]
#
# chain 0:  99%|█████████▉| 9912/10000 [1:12:01<00:24,  3.66it/s]
#
# chain 0:  99%|█████████▉| 9915/10000 [1:12:02<00:17,  4.86it/s]
#
# chain 0:  99%|█████████▉| 9920/10000 [1:12:02<00:09,  8.17it/s]
#
# chain 0:  99%|█████████▉| 9923/10000 [1:12:03<00:10,  7.67it/s]
#
# chain 0:  99%|█████████▉| 9926/10000 [1:12:03<00:11,  6.71it/s]
#
# chain 0:  99%|█████████▉| 9931/10000 [1:12:04<00:09,  7.35it/s]
#
# chain 0:  99%|█████████▉| 9934/10000 [1:12:04<00:06,  9.64it/s]
#
# chain 0:  99%|█████████▉| 9938/10000 [1:12:04<00:08,  7.66it/s]
#
# chain 0:  99%|█████████▉| 9941/10000 [1:12:05<00:07,  7.43it/s]
#
# chain 0:  99%|█████████▉| 9942/10000 [1:12:05<00:07,  7.60it/s]
#
# chain 0:  99%|█████████▉| 9943/10000 [1:12:05<00:08,  6.50it/s]
#
# chain 0:  99%|█████████▉| 9946/10000 [1:12:06<00:08,  6.68it/s]
#
# chain 0: 100%|█████████▉| 9950/10000 [1:12:06<00:05,  8.36it/s]
#
# chain 0: 100%|█████████▉| 9953/10000 [1:12:07<00:07,  6.57it/s]
#
#
#
# chain 0: 100%|█████████▉| 9954/10000 [1:12:07<00:08,  5.45it/s]
#
# chain 0: 100%|█████████▉| 9955/10000 [1:12:07<00:08,  5.59it/s]
#
# chain 0: 100%|█████████▉| 9956/10000 [1:12:07<00:07,  6.07it/s]
#
# chain 0: 100%|█████████▉| 9957/10000 [1:12:07<00:07,  5.44it/s]
#
#
#
#
#
# chain 0: 100%|█████████▉| 9958/10000 [1:12:08<00:10,  3.87it/s]
#
#
#
#
#
#
#
# chain 0: 100%|█████████▉| 9959/10000 [1:12:08<00:14,  2.82it/s]
#
#
#
# chain 0: 100%|█████████▉| 9960/10000 [1:12:09<00:15,  2.51it/s]
#
#
#
# chain 0: 100%|█████████▉| 9961/10000 [1:12:09<00:17,  2.23it/s]
#
#
#
# chain 0: 100%|█████████▉| 9962/10000 [1:12:10<00:16,  2.27it/s]
#
#
#
#
#
# chain 0: 100%|█████████▉| 9963/10000 [1:12:10<00:15,  2.33it/s]
#
#
#
#
#
# chain 0: 100%|█████████▉| 9964/10000 [1:12:11<00:16,  2.21it/s]
#
# chain 0: 100%|█████████▉| 9965/10000 [1:12:11<00:17,  2.02it/s]
#
#
#
#
#
# chain 0: 100%|█████████▉| 9966/10000 [1:12:12<00:15,  2.25it/s]
#
#
#
#
#
# chain 0: 100%|█████████▉| 9967/10000 [1:12:12<00:13,  2.39it/s]
#
#
#
# chain 0: 100%|█████████▉| 9968/10000 [1:12:12<00:11,  2.74it/s]
#
# chain 0: 100%|█████████▉| 9969/10000 [1:12:13<00:10,  2.86it/s]
#
#
#
# chain 0: 100%|█████████▉| 9970/10000 [1:12:13<00:10,  2.86it/s]
#
#
#
#
#
#
#
# chain 0: 100%|█████████▉| 9971/10000 [1:12:13<00:11,  2.52it/s]
#
#
#
# chain 0: 100%|█████████▉| 9973/10000 [1:12:14<00:08,  3.30it/s]
#
# chain 0: 100%|█████████▉| 9974/10000 [1:12:14<00:06,  3.84it/s]
#
# chain 0: 100%|█████████▉| 9975/10000 [1:12:14<00:05,  4.48it/s]
#
# chain 0: 100%|█████████▉| 9977/10000 [1:12:15<00:04,  4.75it/s]
#
#
#
# chain 0: 100%|█████████▉| 9978/10000 [1:12:15<00:06,  3.58it/s]
#
#
#
# chain 0: 100%|█████████▉| 9979/10000 [1:12:16<00:07,  2.94it/s]
#
#
#
# chain 0: 100%|█████████▉| 9980/10000 [1:12:16<00:08,  2.49it/s]
#
# chain 0: 100%|█████████▉| 9982/10000 [1:12:16<00:05,  3.47it/s]
#
# chain 0: 100%|█████████▉| 9985/10000 [1:12:17<00:02,  5.18it/s]
#
# chain 0: 100%|█████████▉| 9987/10000 [1:12:17<00:02,  5.12it/s]
#
# chain 0: 100%|█████████▉| 9990/10000 [1:12:18<00:01,  6.25it/s]
#
# chain 0: 100%|█████████▉| 9994/10000 [1:12:18<00:00,  7.50it/s]
#
# chain 0: 100%|█████████▉| 9997/10000 [1:12:19<00:00,  6.85it/s]
#
# chain 0: 100%|█████████▉| 9998/10000 [1:12:19<00:00,  5.18it/s]
#
#
#
# chain 0: 100%|█████████▉| 9999/10000 [1:12:19<00:00,  3.83it/s]
#
# chain 0: 100%|██████████| 10000/10000 [1:12:20<00:00,  2.30it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chain 3: 100%|██████████| 10000/10000 [1:12:22<00:00,  2.30it/s]

# %%
np.save("test_samples.npy",test_samples)
np.save("statelogdensity.npy",test_meta["state_log_density"])

# %%
test_samples = np.load("test_samples.npy")

print(test_samples.shape)
# Out:
# (4, 10000, 9)

# %%
print(test_samples.shape)
n_samples = 10000
n_burnin = 0
print(np.mean(hopsy.rhat(test_samples[:,n_burnin:,:])))
print("MLDA_ESS",(hopsy.ess(test_samples[:,n_burnin:,:])))
# Out:
# (4, 10000, 9)
# 1.047175263642176
# MLDA_ESS [[133.95301162 143.43839751  89.92854599 272.56325335 213.05881727
#    39.85278032 116.49705366  32.6869996  110.11778242]]

# %%
#plt.plot(range(0, n_samples), meta["state_log_density"][:, n_burnin:].T, ls="-")
plt.figure()
plt.title("state_log_density of first markov-chain w. MALA-Proposal")
plt.xlabel("state-trajectory")
plt.ylabel("state log density")
plt.xlabel("")
plt.plot(range(n_burnin,n_samples), test_meta["state_log_density"][0,n_burnin:].T, ls = "--")
plt.grid()
